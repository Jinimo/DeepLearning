# %% [markdown]
# # Fasion MNIST - CNN ver 1
# - 2 x Conv2D layers
# - MaxPooling2D layer
# - 1 Dropout(0.25) layer
# - 1 FCN layer
# - 1 Dropout(0.5) layer
# - 1 Output layer

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf 
seed = 2022
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
from tensorflow.keras.datasets import fashion_mnist
(X_train, y_train), (X_test, y_test) =  fashion_mnist.load_data() # 데이터 자체에 튜플형식으로 들어가 있음 

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step
# ((60000, 28, 28), (10000, 28, 28), (60000,), (10000,))

# %%
# 이미지 확인 
plt.imshow(X_train[0], cmap='Greys');

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
plt.figure(figsize=(13, 5))
for i in range(1, 11):
  plt.subplot(2, 5, i)
  plt.imshow(X_train[i], cmap='Greys')
  plt.title(class_names[y_train[i]])
  plt.xticks([]), plt.yticks([])
plt.show();

# %%
# X_train, X_test: 정규화(0~1)
# 이미지 차원 변경 
X_train = X_train.reshape(-1, 28,28,1) / 225.
X_test = X_test.reshape(-1, 28,28,1) / 225.

X_train.shape, X_test.shape
# Out:
# ((60000, 28, 28, 1), (10000, 28, 28, 1))

# %%
# Y_train, Y_test: one-hot encodig
from tensorflow.keras.utils import to_categorical
Y_train = to_categorical(y_train)
Y_test = to_categorical(y_test)

Y_train.shape, Y_test.shape
# Out:
# ((60000, 10), (10000, 10))

# %% [markdown]
# 2. 모델 정의/설정/학습/평가

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Conv2D, Flatten, MaxPooling2D, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
model = Sequential([
                    Conv2D(32, kernel_size=(3,3), input_shape=(28,28,1), activation='relu'), # 마스크 개수, 마스크 사이즈 
                    Conv2D(64, (3,3), activation='relu'),
                    MaxPooling2D(),                       # MaxPooling2D(pool_size=(2,2))
                    Dropout(0.25),
                    Flatten(),                            # ----> 1 차원 변경 
                    Dense(512, activation='relu'),
                    Dropout(0.5),
                    Dense(10, activation='softmax')       # feature col num = 10 이여서 

])
model.summary()
## Output Shape 
# (input 개수 + 2 * 패딩 개수 -f/ stride 개수) + 1
# shape 1: (28 + 0 - 3) /1 + 1 = 26  ---> (26, 26, 32)
# shape 2: (26 + 0 - 3) /1 + 1 = 24  ---> (24, 24, 64)

## 파라미터 개수
# 입력채널 수 x 마스크 폭 x 마스크 높이 x 출력채널 수(노드개수) + 출력채널 수
# conv2d_2: 32 x 3 x 3 x 64 + 64 = 18496
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 64)        18496
#
#  max_pooling2d (MaxPooling2D  (None, 12, 12, 64)       0
#  )
#
#  dropout (Dropout)           (None, 12, 12, 64)        0
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 512)               4719104
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 4,743,050
# Trainable params: 4,743,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile('adam', 'categorical_crossentropy', ['accuracy'])

model_path = 'best-fasion-mnist-cnn-v1.h5'
mc = ModelCheckpoint(model_path, save_best_only=True, verbose=1)
es = EarlyStopping(patience=10)

# %%
hist = model.fit(
    X_train, Y_train, validation_split=0.2,
    epochs=100, batch_size=200,
    callbacks=[mc,es]
)
# flatten -> FCN 넘어갈 때 파라미터 수 많아져서 일반 cpu로 돌리면 시간 너무 오래걸림!
# 학습시에 GPU로 변경 후 실행하기
# Out:
# Epoch 1/100
# 237/240 [============================>.] - ETA: 0s - loss: 0.4972 - accuracy: 0.8231
# Epoch 1: val_loss improved from inf to 0.32271, saving model to best-fasion-mnist-cnn-v1.h5
# 240/240 [==============================] - 15s 15ms/step - loss: 0.4958 - accuracy: 0.8237 - val_loss: 0.3227 - val_accuracy: 0.8829
# Epoch 2/100
# 237/240 [============================>.] - ETA: 0s - loss: 0.3106 - accuracy: 0.8881
# Epoch 2: val_loss improved from 0.32271 to 0.27126, saving model to best-fasion-mnist-cnn-v1.h5
# 240/240 [==============================] - 3s 14ms/step - loss: 0.3107 - accuracy: 0.8881 - val_loss: 0.2713 - val_accuracy: 0.9013
# Epoch 3/100
# 239/240 [============================>.] - ETA: 0s - loss: 0.2577 - accuracy: 0.9065
# Epoch 3: val_loss improved from 0.27126 to 0.23675, saving model to best-fasion-mnist-cnn-v1.h5
# 240/240 [==============================] - 3s 14ms/step - loss: 0.2579 - accuracy: 0.9064 - val_loss: 0.2367 - val_accuracy: 0.9126
# Epoch 4/100
# 240/240 [==============================] - ETA: 0s - loss: 0.2248 - accuracy: 0.9172
# Epoch 4: val_loss improved from 0.23675 to 0.23052, saving model to best-fasion-mnist-cnn-v1.h5
# 240/240 [==============================] - 3s 14ms/step - loss: 0.2248 - accuracy: 0.9172 - val_loss: 0.2305 - val_accuracy: 0.9156
# Epoch 5/100
# 237/240 [============================>.] - ETA: 0s - loss: 0.1983 - accuracy: 0.9264
# Epoch 5: val_loss improved from 0.23052 to 0.22567, saving model to best-fasion-mnist-cnn-v1.h5
# 240/240 [==============================] - 3s 14ms/step - loss: 0.1983 - accuracy: 0.9263 - val_loss: 0.2257 - val_accuracy: 0.9161
# Epoch 6/100
# 237/240 [============================>.] - ETA: 0s - loss: 0.1761 - accuracy: 0.9356
# Epoch 6: val_loss improved from 0.22567 to 0.21639, saving model to best-fasion-mnist-cnn-v1.h5
# 240/240 [==============================] - 3s 14ms/step - loss: 0.1763 - accuracy: 0.9355 - val_loss: 0.2164 - val_accuracy: 0.9210
# Epoch 7/100
# 237/240 [============================>.] - ETA: 0s - loss: 0.1550 - accuracy: 0.9422
# Epoch 7: val_loss improved from 0.21639 to 0.20639, saving model to best-fasion-mnist-cnn-v1.h5
# 240/240 [==============================] - 3s 14ms/step - loss: 0.1551 - accuracy: 0.9422 - val_loss: 0.2064 - val_accuracy: 0.9263
# Epoch 8/100
# 238/240 [============================>.] - ETA: 0s - loss: 0.1361 - accuracy: 0.9490
# Epoch 8: val_loss improved from 0.20639 to 0.20340, saving model to best-fasion-mnist-cnn-v1.h5
# 240/240 [==============================] - 3s 14ms/step - loss: 0.1366 - accuracy: 0.9489 - val_loss: 0.2034 - val_accuracy: 0.9292
# Epoch 9/100
# 238/240 [============================>.] - ETA: 0s - loss: 0.1256 - accuracy: 0.9536
# Epoch 9: val_loss improved from 0.20340 to 0.20195, saving model to best-fasion-mnist-cnn-v1.h5
# 240/240 [==============================] - 4s 15ms/step - loss: 0.1257 - accuracy: 0.9535 - val_loss: 0.2020 - val_accuracy: 0.9292
# Epoch 10/100
# 240/240 [==============================] - ETA: 0s - loss: 0.1079 - accuracy: 0.9608
# Epoch 10: val_loss did not improve from 0.20195
# 240/240 [==============================] - 3s 14ms/step - loss: 0.1079 - accuracy: 0.9608 - val_loss: 0.2205 - val_accuracy: 0.9253
# Epoch 11/100
# 237/240 [============================>.] - ETA: 0s - loss: 0.0954 - accuracy: 0.9656
# Epoch 11: val_loss did not improve from 0.20195
# 240/240 [==============================] - 3s 14ms/step - loss: 0.0956 - accuracy: 0.9655 - val_loss: 0.2101 - val_accuracy: 0.9312
# Epoch 12/100
# 237/240 [============================>.] - ETA: 0s - loss: 0.0883 - accuracy: 0.9668
# Epoch 12: val_loss did not improve from 0.20195
# 240/240 [==============================] - 3s 14ms/step - loss: 0.0884 - accuracy: 0.9668 - val_loss: 0.2142 - val_accuracy: 0.9293
# Epoch 13/100
# 237/240 [============================>.] - ETA: 0s - loss: 0.0758 - accuracy: 0.9717
# Epoch 13: val_loss did not improve from 0.20195
# 240/240 [==============================] - 3s 14ms/step - loss: 0.0759 - accuracy: 0.9717 - val_loss: 0.2278 - val_accuracy: 0.9303
# Epoch 14/100
# 240/240 [==============================] - ETA: 0s - loss: 0.0695 - accuracy: 0.9742
# Epoch 14: val_loss did not improve from 0.20195
# 240/240 [==============================] - 4s 15ms/step - loss: 0.0695 - accuracy: 0.9742 - val_loss: 0.2386 - val_accuracy: 0.9298
# Epoch 15/100
# 237/240 [============================>.] - ETA: 0s - loss: 0.0669 - accuracy: 0.9749
# Epoch 15: val_loss did not improve from 0.20195
# 240/240 [==============================] - 4s 15ms/step - loss: 0.0674 - accuracy: 0.9748 - val_loss: 0.2332 - val_accuracy: 0.9298
# Epoch 16/100
# 239/240 [============================>.] - ETA: 0s - loss: 0.0594 - accuracy: 0.9785
# Epoch 16: val_loss did not improve from 0.20195
# 240/240 [==============================] - 3s 14ms/step - loss: 0.0594 - accuracy: 0.9785 - val_loss: 0.2417 - val_accuracy: 0.9307
# Epoch 17/100
# 239/240 [============================>.] - ETA: 0s - loss: 0.0503 - accuracy: 0.9818
# Epoch 17: val_loss did not improve from 0.20195
# 240/240 [==============================] - 3s 14ms/step - loss: 0.0503 - accuracy: 0.9818 - val_loss: 0.2405 - val_accuracy: 0.9320
# Epoch 18/100
# 240/240 [==============================] - ETA: 0s - loss: 0.0484 - accuracy: 0.9827
# Epoch 18: val_loss did not improve from 0.20195
# 240/240 [==============================] - 3s 14ms/step - loss: 0.0484 - accuracy: 0.9827 - val_loss: 0.2566 - val_accuracy: 0.9308
# Epoch 19/100
# 237/240 [============================>.] - ETA: 0s - loss: 0.0446 - accuracy: 0.9837
# Epoch 19: val_loss did not improve from 0.20195
# 240/240 [==============================] - 3s 14ms/step - loss: 0.0446 - accuracy: 0.9837 - val_loss: 0.2597 - val_accuracy: 0.9305

# %%
best_model = load_model(model_path)
best_model.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.2119 - accuracy: 0.9251
# [0.21190856397151947, 0.9251000285148621]

# %% [markdown]
# 3. 학습 과정 시각화

# %%
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs =np.arange(1, len(y_acc)+1) # 시작을 1번부터 해주기 위해서

# %%
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, label='train accuracy')
plt.plot(xs, y_vloss, label='train loss')
plt.legend(), plt.grid()
plt.title('Fasion MNIST CNN model v1')
plt.show()
