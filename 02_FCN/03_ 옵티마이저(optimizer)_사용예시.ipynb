# %% [markdown]
# # 신경망 모델에서 옵티마이저 사용법

# %% [markdown]
# - 이진분류
# - 사용 데이터: 유방암 예측 사례

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
cancer = load_breast_cancer()
cancer_std = StandardScaler().fit_transform(cancer.data)

X_train, X_test, y_train, y_test = train_test_split(
    cancer.data, cancer.target, stratify=cancer.target,
    test_size=0.2, random_state=2022
)

# %% [markdown]
# ### 1. `Adam` optimizer 사용

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential([
                    Dense(100, input_dim=30, activation='relu'), 
                    Dense(24,  activation='relu'), 
                    Dense(1, input_dim=30, activation='sigmoid')
])

# %% [markdown]
# #### `Adam` 하이퍼 파라메터
# - `learning_rate`: 0보다 크거나 같은 float 값. 학습률.
# - `beta_1`: 0보다 크고 1보다 작은 float 값. 일반적으로 1에 가깝게 설정됩니다.
# - `beta_2`: 0보다 크고 1보다 작은 float 값. 일반적으로 1에 가깝게 설정됩니다.
# - `epsilon`: 0보다 크거나 같은 float형 fuzz factor. None인 경우 K.epsilon()이 사용됩니다.
# - `decay`: 0보다 크거나 같은 float 값. 업데이트마다 적용되는 학습률의 감소율입니다.
# - `amsgrad`: 불리언. Adam의 변형인 AMSGrad의 적용 여부를 설정합니다

# %%
# 일단 그냥 하이퍼 파라미터 조정할 수 있다는 점만 알아두기
# 하이퍼 파라미터 조정은 나중에 더 학습 후 사용 
from tensorflow.keras.optimizers import Adam
adam = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, 
            epsilon=None, decay=0.0, amsgrad=False )

# %%
model.compile(optimizer=adam, loss='binary_crossentropy', metrics=['accuracy'])
# optimizer 기본 사용 -> optimizer = 'adam' (string)
# 여기서는 하이퍼파라미터 값 조정하여 adam 변수에 할당하여 optimizer = adam (변수)

# %%
hist = model.fit(X_train, y_train, validation_split = 0.2,
                 epochs = 100, batch_size=100, verbose=0)

# %%
model.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2415 - accuracy: 0.9035
# [0.24152758717536926, 0.9035087823867798]

# %%
y_acc = hist.history['accuracy']
y_loss = hist.history['val_loss']

xs = np.arange(1, len(y_acc)+1)

# %%
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, label='accuracy')
plt.plot(xs, y_loss, label='Validation loss')
plt.legend(), plt.grid()
plt.xlabel('Epoch')
plt.ylabel('No feature transform')
plt.ylim([0, 1])
plt.show()

# %% [markdown]
# ### 2. `RMSprop` optimizer 사용

# %%
model2 = Sequential([
                    Dense(100, input_dim=30, activation='relu'), 
                    Dense(24,  activation='relu'), 
                    Dense(1, input_dim=30, activation='sigmoid')
])

# %% [markdown]
# #### `RMSprop` 하이퍼 파라메터
# - `lr`: 0보다 크거나 같은 float 값. 학습률.
# - `rho`: 0보다 크거나 같은 float 값.
# - `epsilon`: 0보다 크거나 같은 float형 fuzz factor. None인 경우 `K.epsilon()`이 사용됩니다.
# - `decay`: 0보다 크거나 같은 float 값. 업데이트마다 적용되는 학습률의 감소율입니다.

# %%
from tensorflow.keras.optimizers import RMSprop
rmsp = RMSprop(learning_rate=0.001, rho=0.9, epsilon=None, decay=0.0)

# %%
model2.compile(rmsp, 'binary_crossentropy', ['accuracy'])

# %%
hist2 = model2.fit(X_train, y_train, validation_split=0.2, 
                   epochs=100, batch_size=100, verbose=2)
# verbose = 0/1/2
# Out:
# Epoch 1/100
# 4/4 - 2s - loss: 24.6246 - accuracy: 0.4203 - val_loss: 2.0972 - val_accuracy: 0.4835 - 2s/epoch - 397ms/step
# Epoch 2/100
# 4/4 - 0s - loss: 5.9688 - accuracy: 0.5192 - val_loss: 3.9578 - val_accuracy: 0.6703 - 50ms/epoch - 13ms/step
# Epoch 3/100
# 4/4 - 0s - loss: 5.8464 - accuracy: 0.5247 - val_loss: 3.7774 - val_accuracy: 0.7253 - 60ms/epoch - 15ms/step
# Epoch 4/100
# 4/4 - 0s - loss: 5.0212 - accuracy: 0.5769 - val_loss: 1.1839 - val_accuracy: 0.8242 - 57ms/epoch - 14ms/step
# Epoch 5/100
# 4/4 - 0s - loss: 2.6758 - accuracy: 0.6346 - val_loss: 3.1939 - val_accuracy: 0.7582 - 50ms/epoch - 12ms/step
# Epoch 6/100
# 4/4 - 0s - loss: 3.7228 - accuracy: 0.5769 - val_loss: 1.8639 - val_accuracy: 0.8242 - 54ms/epoch - 14ms/step
# Epoch 7/100
# 4/4 - 0s - loss: 2.9458 - accuracy: 0.6016 - val_loss: 2.0771 - val_accuracy: 0.8242 - 59ms/epoch - 15ms/step
# Epoch 8/100
# 4/4 - 0s - loss: 2.9411 - accuracy: 0.6126 - val_loss: 2.1993 - val_accuracy: 0.8242 - 62ms/epoch - 15ms/step
# Epoch 9/100
# 4/4 - 0s - loss: 1.6550 - accuracy: 0.7775 - val_loss: 1.3105 - val_accuracy: 0.8462 - 55ms/epoch - 14ms/step
# Epoch 10/100
# 4/4 - 0s - loss: 1.2424 - accuracy: 0.8022 - val_loss: 1.8973 - val_accuracy: 0.8242 - 53ms/epoch - 13ms/step
# Epoch 11/100
# 4/4 - 0s - loss: 2.8629 - accuracy: 0.6484 - val_loss: 1.1235 - val_accuracy: 0.8571 - 62ms/epoch - 15ms/step
# Epoch 12/100
# 4/4 - 0s - loss: 1.3231 - accuracy: 0.7637 - val_loss: 1.2167 - val_accuracy: 0.8571 - 50ms/epoch - 13ms/step
# Epoch 13/100
# 4/4 - 0s - loss: 0.8776 - accuracy: 0.8324 - val_loss: 0.6371 - val_accuracy: 0.9011 - 53ms/epoch - 13ms/step
# Epoch 14/100
# 4/4 - 0s - loss: 0.6869 - accuracy: 0.8544 - val_loss: 0.9253 - val_accuracy: 0.8681 - 51ms/epoch - 13ms/step
# Epoch 15/100
# 4/4 - 0s - loss: 4.9822 - accuracy: 0.6071 - val_loss: 3.5010 - val_accuracy: 0.7912 - 57ms/epoch - 14ms/step
# Epoch 16/100
# 4/4 - 0s - loss: 1.2823 - accuracy: 0.8352 - val_loss: 0.6115 - val_accuracy: 0.8462 - 49ms/epoch - 12ms/step
# Epoch 17/100
# 4/4 - 0s - loss: 0.7597 - accuracy: 0.8214 - val_loss: 1.3724 - val_accuracy: 0.8352 - 55ms/epoch - 14ms/step
# Epoch 18/100
# 4/4 - 0s - loss: 3.9758 - accuracy: 0.6484 - val_loss: 2.5409 - val_accuracy: 0.8242 - 67ms/epoch - 17ms/step
# Epoch 19/100
# 4/4 - 0s - loss: 1.5872 - accuracy: 0.7885 - val_loss: 1.8057 - val_accuracy: 0.8462 - 57ms/epoch - 14ms/step
# Epoch 20/100
# 4/4 - 0s - loss: 2.4227 - accuracy: 0.7005 - val_loss: 1.9485 - val_accuracy: 0.8462 - 67ms/epoch - 17ms/step
# Epoch 21/100
# 4/4 - 0s - loss: 1.3750 - accuracy: 0.8159 - val_loss: 0.9119 - val_accuracy: 0.8901 - 61ms/epoch - 15ms/step
# Epoch 22/100
# 4/4 - 0s - loss: 0.5946 - accuracy: 0.8764 - val_loss: 0.5470 - val_accuracy: 0.9011 - 64ms/epoch - 16ms/step
# Epoch 23/100
# 4/4 - 0s - loss: 0.4676 - accuracy: 0.9011 - val_loss: 0.8577 - val_accuracy: 0.8901 - 65ms/epoch - 16ms/step
# Epoch 24/100
# 4/4 - 0s - loss: 3.6123 - accuracy: 0.6566 - val_loss: 2.0857 - val_accuracy: 0.8462 - 62ms/epoch - 15ms/step
# Epoch 25/100
# 4/4 - 0s - loss: 1.2655 - accuracy: 0.8379 - val_loss: 0.7134 - val_accuracy: 0.9231 - 78ms/epoch - 19ms/step
# Epoch 26/100
# 4/4 - 0s - loss: 1.0333 - accuracy: 0.8434 - val_loss: 0.6966 - val_accuracy: 0.8462 - 56ms/epoch - 14ms/step
# Epoch 27/100
# 4/4 - 0s - loss: 1.1905 - accuracy: 0.8104 - val_loss: 1.5069 - val_accuracy: 0.7143 - 89ms/epoch - 22ms/step
# Epoch 28/100
# 4/4 - 0s - loss: 0.8632 - accuracy: 0.8681 - val_loss: 2.1278 - val_accuracy: 0.5934 - 69ms/epoch - 17ms/step
# Epoch 29/100
# 4/4 - 0s - loss: 4.3623 - accuracy: 0.6291 - val_loss: 0.6311 - val_accuracy: 0.8681 - 59ms/epoch - 15ms/step
# Epoch 30/100
# 4/4 - 0s - loss: 0.5625 - accuracy: 0.8901 - val_loss: 0.6871 - val_accuracy: 0.8462 - 58ms/epoch - 14ms/step
# Epoch 31/100
# 4/4 - 0s - loss: 0.5523 - accuracy: 0.8791 - val_loss: 1.1670 - val_accuracy: 0.8791 - 55ms/epoch - 14ms/step
# Epoch 32/100
# 4/4 - 0s - loss: 2.6556 - accuracy: 0.7198 - val_loss: 2.6786 - val_accuracy: 0.8132 - 73ms/epoch - 18ms/step
# Epoch 33/100
# 4/4 - 0s - loss: 0.9084 - accuracy: 0.8956 - val_loss: 0.5678 - val_accuracy: 0.9011 - 66ms/epoch - 16ms/step
# Epoch 34/100
# 4/4 - 0s - loss: 0.4563 - accuracy: 0.9038 - val_loss: 0.6413 - val_accuracy: 0.9121 - 62ms/epoch - 15ms/step
# Epoch 35/100
# 4/4 - 0s - loss: 0.8506 - accuracy: 0.8571 - val_loss: 6.2503 - val_accuracy: 0.7033 - 54ms/epoch - 13ms/step
# Epoch 36/100
# 4/4 - 0s - loss: 3.2104 - accuracy: 0.7005 - val_loss: 2.9207 - val_accuracy: 0.8132 - 69ms/epoch - 17ms/step
# Epoch 37/100
# 4/4 - 0s - loss: 1.6100 - accuracy: 0.8434 - val_loss: 0.7617 - val_accuracy: 0.9231 - 59ms/epoch - 15ms/step
# Epoch 38/100
# 4/4 - 0s - loss: 1.2939 - accuracy: 0.8269 - val_loss: 1.0182 - val_accuracy: 0.8901 - 56ms/epoch - 14ms/step
# Epoch 39/100
# 4/4 - 0s - loss: 0.7665 - accuracy: 0.8901 - val_loss: 1.5691 - val_accuracy: 0.8681 - 61ms/epoch - 15ms/step
# Epoch 40/100
# 4/4 - 0s - loss: 0.9630 - accuracy: 0.8764 - val_loss: 1.6092 - val_accuracy: 0.8681 - 59ms/epoch - 15ms/step
# Epoch 41/100
# 4/4 - 0s - loss: 2.4412 - accuracy: 0.7445 - val_loss: 3.6708 - val_accuracy: 0.7692 - 66ms/epoch - 16ms/step
# Epoch 42/100
# 4/4 - 0s - loss: 1.4251 - accuracy: 0.8544 - val_loss: 0.5946 - val_accuracy: 0.8901 - 53ms/epoch - 13ms/step
# Epoch 43/100
# 4/4 - 0s - loss: 0.5407 - accuracy: 0.8984 - val_loss: 0.7104 - val_accuracy: 0.8352 - 53ms/epoch - 13ms/step
# Epoch 44/100
# 4/4 - 0s - loss: 0.6226 - accuracy: 0.8874 - val_loss: 0.5822 - val_accuracy: 0.8901 - 52ms/epoch - 13ms/step
# Epoch 45/100
# 4/4 - 0s - loss: 0.9281 - accuracy: 0.8681 - val_loss: 6.5284 - val_accuracy: 0.3736 - 66ms/epoch - 16ms/step
# Epoch 46/100
# 4/4 - 0s - loss: 3.6438 - accuracy: 0.6978 - val_loss: 0.6860 - val_accuracy: 0.8462 - 64ms/epoch - 16ms/step
# Epoch 47/100
# 4/4 - 0s - loss: 0.4281 - accuracy: 0.9011 - val_loss: 0.5710 - val_accuracy: 0.9231 - 78ms/epoch - 20ms/step
# Epoch 48/100
# 4/4 - 0s - loss: 0.3989 - accuracy: 0.9258 - val_loss: 0.9757 - val_accuracy: 0.8022 - 69ms/epoch - 17ms/step
# Epoch 49/100
# 4/4 - 0s - loss: 1.9735 - accuracy: 0.7802 - val_loss: 0.7084 - val_accuracy: 0.8462 - 71ms/epoch - 18ms/step
# Epoch 50/100
# 4/4 - 0s - loss: 0.4875 - accuracy: 0.9066 - val_loss: 1.1441 - val_accuracy: 0.7912 - 65ms/epoch - 16ms/step
# Epoch 51/100
# 4/4 - 0s - loss: 1.2857 - accuracy: 0.8489 - val_loss: 5.5469 - val_accuracy: 0.3956 - 62ms/epoch - 15ms/step
# Epoch 52/100
# 4/4 - 0s - loss: 2.8276 - accuracy: 0.7088 - val_loss: 0.5898 - val_accuracy: 0.9231 - 57ms/epoch - 14ms/step
# Epoch 53/100
# 4/4 - 0s - loss: 0.4119 - accuracy: 0.9121 - val_loss: 0.6035 - val_accuracy: 0.9231 - 61ms/epoch - 15ms/step
# Epoch 54/100
# 4/4 - 0s - loss: 0.4128 - accuracy: 0.9121 - val_loss: 0.7092 - val_accuracy: 0.9121 - 58ms/epoch - 15ms/step
# Epoch 55/100
# 4/4 - 0s - loss: 0.9885 - accuracy: 0.8681 - val_loss: 5.6481 - val_accuracy: 0.7143 - 80ms/epoch - 20ms/step
# Epoch 56/100
# 4/4 - 0s - loss: 2.4987 - accuracy: 0.7940 - val_loss: 0.6186 - val_accuracy: 0.9231 - 81ms/epoch - 20ms/step
# Epoch 57/100
# 4/4 - 0s - loss: 0.7232 - accuracy: 0.8956 - val_loss: 2.1499 - val_accuracy: 0.6923 - 100ms/epoch - 25ms/step
# Epoch 58/100
# 4/4 - 0s - loss: 1.6326 - accuracy: 0.8022 - val_loss: 0.5929 - val_accuracy: 0.9231 - 192ms/epoch - 48ms/step
# Epoch 59/100
# 4/4 - 0s - loss: 0.7520 - accuracy: 0.8681 - val_loss: 0.9279 - val_accuracy: 0.8352 - 196ms/epoch - 49ms/step
# Epoch 60/100
# 4/4 - 0s - loss: 0.9609 - accuracy: 0.8599 - val_loss: 0.6119 - val_accuracy: 0.8901 - 176ms/epoch - 44ms/step
# Epoch 61/100
# 4/4 - 0s - loss: 0.6802 - accuracy: 0.8929 - val_loss: 1.8217 - val_accuracy: 0.8681 - 142ms/epoch - 36ms/step
# Epoch 62/100
# 4/4 - 0s - loss: 2.4509 - accuracy: 0.7500 - val_loss: 0.7299 - val_accuracy: 0.9121 - 160ms/epoch - 40ms/step
# Epoch 63/100
# 4/4 - 0s - loss: 0.6342 - accuracy: 0.8929 - val_loss: 0.8376 - val_accuracy: 0.8571 - 76ms/epoch - 19ms/step
# Epoch 64/100
# 4/4 - 0s - loss: 0.4133 - accuracy: 0.9121 - val_loss: 0.6148 - val_accuracy: 0.9231 - 88ms/epoch - 22ms/step
# Epoch 65/100
# 4/4 - 0s - loss: 0.4152 - accuracy: 0.9231 - val_loss: 1.2422 - val_accuracy: 0.7802 - 65ms/epoch - 16ms/step
# Epoch 66/100
# 4/4 - 0s - loss: 3.3079 - accuracy: 0.7253 - val_loss: 0.6983 - val_accuracy: 0.8681 - 50ms/epoch - 13ms/step
# Epoch 67/100
# 4/4 - 0s - loss: 0.4490 - accuracy: 0.9066 - val_loss: 0.6013 - val_accuracy: 0.9121 - 68ms/epoch - 17ms/step
# Epoch 68/100
# 4/4 - 0s - loss: 0.6406 - accuracy: 0.8819 - val_loss: 2.8478 - val_accuracy: 0.8132 - 54ms/epoch - 13ms/step
# Epoch 69/100
# 4/4 - 0s - loss: 1.4949 - accuracy: 0.8489 - val_loss: 1.1216 - val_accuracy: 0.9011 - 160ms/epoch - 40ms/step
# Epoch 70/100
# 4/4 - 0s - loss: 1.4994 - accuracy: 0.8104 - val_loss: 0.8683 - val_accuracy: 0.9011 - 160ms/epoch - 40ms/step
# Epoch 71/100
# 4/4 - 0s - loss: 0.7217 - accuracy: 0.8929 - val_loss: 0.6241 - val_accuracy: 0.9011 - 161ms/epoch - 40ms/step
# Epoch 72/100
# 4/4 - 0s - loss: 2.1008 - accuracy: 0.7802 - val_loss: 4.5786 - val_accuracy: 0.4835 - 160ms/epoch - 40ms/step
# Epoch 73/100
# 4/4 - 0s - loss: 2.1826 - accuracy: 0.7692 - val_loss: 0.7070 - val_accuracy: 0.9121 - 103ms/epoch - 26ms/step
# Epoch 74/100
# 4/4 - 0s - loss: 0.5130 - accuracy: 0.9148 - val_loss: 0.6011 - val_accuracy: 0.9121 - 141ms/epoch - 35ms/step
# Epoch 75/100
# 4/4 - 0s - loss: 0.3801 - accuracy: 0.9258 - val_loss: 0.6177 - val_accuracy: 0.9121 - 70ms/epoch - 18ms/step
# Epoch 76/100
# 4/4 - 0s - loss: 0.4134 - accuracy: 0.9038 - val_loss: 0.7254 - val_accuracy: 0.8681 - 62ms/epoch - 16ms/step
# Epoch 77/100
# 4/4 - 0s - loss: 1.9510 - accuracy: 0.7967 - val_loss: 3.7058 - val_accuracy: 0.5275 - 60ms/epoch - 15ms/step
# Epoch 78/100
# 4/4 - 0s - loss: 1.6369 - accuracy: 0.8104 - val_loss: 0.6128 - val_accuracy: 0.9121 - 52ms/epoch - 13ms/step
# Epoch 79/100
# 4/4 - 0s - loss: 0.4333 - accuracy: 0.9121 - val_loss: 0.6535 - val_accuracy: 0.9121 - 55ms/epoch - 14ms/step
# Epoch 80/100
# 4/4 - 0s - loss: 0.4817 - accuracy: 0.9148 - val_loss: 2.3375 - val_accuracy: 0.6923 - 55ms/epoch - 14ms/step
# Epoch 81/100
# 4/4 - 0s - loss: 1.7700 - accuracy: 0.8159 - val_loss: 0.6218 - val_accuracy: 0.9121 - 66ms/epoch - 16ms/step
# Epoch 82/100
# 4/4 - 0s - loss: 0.3999 - accuracy: 0.9203 - val_loss: 0.6313 - val_accuracy: 0.9231 - 61ms/epoch - 15ms/step
# Epoch 83/100
# 4/4 - 0s - loss: 0.4195 - accuracy: 0.9203 - val_loss: 1.5067 - val_accuracy: 0.8791 - 57ms/epoch - 14ms/step
# Epoch 84/100
# 4/4 - 0s - loss: 2.2262 - accuracy: 0.7692 - val_loss: 2.7167 - val_accuracy: 0.8132 - 57ms/epoch - 14ms/step
# Epoch 85/100
# 4/4 - 0s - loss: 1.2828 - accuracy: 0.8984 - val_loss: 0.6207 - val_accuracy: 0.9121 - 60ms/epoch - 15ms/step
# Epoch 86/100
# 4/4 - 0s - loss: 0.3812 - accuracy: 0.9203 - val_loss: 0.6278 - val_accuracy: 0.9231 - 51ms/epoch - 13ms/step
# Epoch 87/100
# 4/4 - 0s - loss: 0.4942 - accuracy: 0.9148 - val_loss: 1.4130 - val_accuracy: 0.8791 - 66ms/epoch - 17ms/step
# Epoch 88/100
# 4/4 - 0s - loss: 0.5705 - accuracy: 0.9093 - val_loss: 0.9314 - val_accuracy: 0.9011 - 57ms/epoch - 14ms/step
# Epoch 89/100
# 4/4 - 0s - loss: 2.1530 - accuracy: 0.8269 - val_loss: 2.2841 - val_accuracy: 0.7033 - 67ms/epoch - 17ms/step
# Epoch 90/100
# 4/4 - 0s - loss: 1.5823 - accuracy: 0.8104 - val_loss: 1.6771 - val_accuracy: 0.7473 - 84ms/epoch - 21ms/step
# Epoch 91/100
# 4/4 - 0s - loss: 1.2566 - accuracy: 0.8297 - val_loss: 0.5960 - val_accuracy: 0.9231 - 63ms/epoch - 16ms/step
# Epoch 92/100
# 4/4 - 0s - loss: 0.3987 - accuracy: 0.9203 - val_loss: 0.5576 - val_accuracy: 0.9121 - 68ms/epoch - 17ms/step
# Epoch 93/100
# 4/4 - 0s - loss: 0.4116 - accuracy: 0.9093 - val_loss: 0.8232 - val_accuracy: 0.8462 - 82ms/epoch - 21ms/step
# Epoch 94/100
# 4/4 - 0s - loss: 0.2866 - accuracy: 0.9341 - val_loss: 1.1722 - val_accuracy: 0.7802 - 63ms/epoch - 16ms/step
# Epoch 95/100
# 4/4 - 0s - loss: 1.3674 - accuracy: 0.8379 - val_loss: 0.5358 - val_accuracy: 0.9231 - 62ms/epoch - 15ms/step
# Epoch 96/100
# 4/4 - 0s - loss: 0.4266 - accuracy: 0.9148 - val_loss: 0.8433 - val_accuracy: 0.9011 - 60ms/epoch - 15ms/step
# Epoch 97/100
# 4/4 - 0s - loss: 1.2925 - accuracy: 0.8407 - val_loss: 0.5940 - val_accuracy: 0.9231 - 59ms/epoch - 15ms/step
# Epoch 98/100
# 4/4 - 0s - loss: 0.4604 - accuracy: 0.9231 - val_loss: 0.9411 - val_accuracy: 0.9011 - 56ms/epoch - 14ms/step
# Epoch 99/100
# 4/4 - 0s - loss: 2.2722 - accuracy: 0.7418 - val_loss: 1.1198 - val_accuracy: 0.9011 - 52ms/epoch - 13ms/step
# Epoch 100/100
# 4/4 - 0s - loss: 0.7017 - accuracy: 0.9011 - val_loss: 0.6158 - val_accuracy: 0.8901 - 61ms/epoch - 15ms/step

# %%
model2.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7633 - accuracy: 0.8684
# [0.7632769346237183, 0.8684210777282715]

# %%
y_acc2 = hist2.history['accuracy']
y_loss2 = hist2.history['val_loss']

xs = np.arange(1, len(y_acc2)+1)

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.plot(xs, y_acc, label='accuracy')
plt.plot(xs, y_loss, label='Validation loss')
plt.legend(), plt.grid()
plt.xlabel('Epoch')
plt.ylabel('Adam optimizer')
plt.ylim([0, 1])

plt.figure(figsize=(10,5))
plt.subplot(1,2,2)
plt.plot(xs, y_acc2, label='accuracy')
plt.plot(xs, y_loss2, label='Validation loss')
plt.legend(), plt.grid()
plt.xlabel('Epoch')
plt.ylabel('RMSprop optimizer')
plt.ylim([0, 1])
plt.show()
