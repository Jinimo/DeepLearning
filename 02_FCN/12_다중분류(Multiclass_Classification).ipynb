# %% [markdown]
# # 다중 분류
# - 사용 데이터: Iris

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
seed = 2022
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# 1. 데이터 전처리

# %%
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# %%
iris = load_iris()
iris_std = StandardScaler().fit_transform(iris.data) # X - 정규화
y_onehot = to_categorical(iris.target)               # Y - 원핫인코딩

X_train, X_test, Y_train, Y_test = train_test_split(
    iris_std, y_onehot, stratify=y_onehot ,test_size=0.2, random_state=seed
)

# %% [markdown]
# 2. 모델 정의/설정/학습/평가

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
model = Sequential([
                    Dense(12, input_dim=4, activation='relu'),
                    Dense(8, activation='relu'),
                    Dense(3, activation='softmax') # 다중분류니까 출력: 3개, 활성화함수: softmax
])

# %%
model.compile('adam', 'categorical_crossentropy', ['accuracy']) # 'categorical_crossentropy'

# %%
mc = ModelCheckpoint('iirs3_best.h5', monitor='val_loss', verbose=1, save_best_only=True)

es = EarlyStopping(patience=30)

# %%
hist = model.fit(X_train, Y_train, validation_split=0.2,
                 epochs=1000, batch_size=100, verbose=0,
                 callbacks=[mc,es])
# Out:
# Epoch 1: val_loss improved from inf to 1.22967, saving model to iirs3_best.h5
#
# Epoch 2: val_loss improved from 1.22967 to 1.22161, saving model to iirs3_best.h5
#
# Epoch 3: val_loss improved from 1.22161 to 1.21356, saving model to iirs3_best.h5
#
# Epoch 4: val_loss improved from 1.21356 to 1.20554, saving model to iirs3_best.h5
#
# Epoch 5: val_loss improved from 1.20554 to 1.19754, saving model to iirs3_best.h5
#
# Epoch 6: val_loss improved from 1.19754 to 1.18948, saving model to iirs3_best.h5
#
# Epoch 7: val_loss improved from 1.18948 to 1.18150, saving model to iirs3_best.h5
#
# Epoch 8: val_loss improved from 1.18150 to 1.17360, saving model to iirs3_best.h5
#
# Epoch 9: val_loss improved from 1.17360 to 1.16575, saving model to iirs3_best.h5
#
# Epoch 10: val_loss improved from 1.16575 to 1.15808, saving model to iirs3_best.h5
#
# Epoch 11: val_loss improved from 1.15808 to 1.15050, saving model to iirs3_best.h5
#
# Epoch 12: val_loss improved from 1.15050 to 1.14297, saving model to iirs3_best.h5
#
# Epoch 13: val_loss improved from 1.14297 to 1.13550, saving model to iirs3_best.h5
#
# Epoch 14: val_loss improved from 1.13550 to 1.12810, saving model to iirs3_best.h5
#
# Epoch 15: val_loss improved from 1.12810 to 1.12085, saving model to iirs3_best.h5
#
# Epoch 16: val_loss improved from 1.12085 to 1.11360, saving model to iirs3_best.h5
#
# Epoch 17: val_loss improved from 1.11360 to 1.10577, saving model to iirs3_best.h5
#
# Epoch 18: val_loss improved from 1.10577 to 1.09784, saving model to iirs3_best.h5
#
# Epoch 19: val_loss improved from 1.09784 to 1.08996, saving model to iirs3_best.h5
#
# Epoch 20: val_loss improved from 1.08996 to 1.08218, saving model to iirs3_best.h5
#
# Epoch 21: val_loss improved from 1.08218 to 1.07461, saving model to iirs3_best.h5
#
# Epoch 22: val_loss improved from 1.07461 to 1.06717, saving model to iirs3_best.h5
#
# Epoch 23: val_loss improved from 1.06717 to 1.05981, saving model to iirs3_best.h5
#
# Epoch 24: val_loss improved from 1.05981 to 1.05251, saving model to iirs3_best.h5
#
# Epoch 25: val_loss improved from 1.05251 to 1.04516, saving model to iirs3_best.h5
#
# Epoch 26: val_loss improved from 1.04516 to 1.03789, saving model to iirs3_best.h5
#
# Epoch 27: val_loss improved from 1.03789 to 1.03065, saving model to iirs3_best.h5
#
# Epoch 28: val_loss improved from 1.03065 to 1.02347, saving model to iirs3_best.h5
#
# Epoch 29: val_loss improved from 1.02347 to 1.01606, saving model to iirs3_best.h5
#
# Epoch 30: val_loss improved from 1.01606 to 1.00849, saving model to iirs3_best.h5
#
# Epoch 31: val_loss improved from 1.00849 to 1.00096, saving model to iirs3_best.h5
#
# Epoch 32: val_loss improved from 1.00096 to 0.99342, saving model to iirs3_best.h5
#
# Epoch 33: val_loss improved from 0.99342 to 0.98593, saving model to iirs3_best.h5
#
# Epoch 34: val_loss improved from 0.98593 to 0.97851, saving model to iirs3_best.h5
#
# Epoch 35: val_loss improved from 0.97851 to 0.97122, saving model to iirs3_best.h5
#
# Epoch 36: val_loss improved from 0.97122 to 0.96408, saving model to iirs3_best.h5
#
# Epoch 37: val_loss improved from 0.96408 to 0.95719, saving model to iirs3_best.h5
#
# Epoch 38: val_loss improved from 0.95719 to 0.95038, saving model to iirs3_best.h5
#
# Epoch 39: val_loss improved from 0.95038 to 0.94366, saving model to iirs3_best.h5
#
# Epoch 40: val_loss improved from 0.94366 to 0.93704, saving model to iirs3_best.h5
#
# Epoch 41: val_loss improved from 0.93704 to 0.93013, saving model to iirs3_best.h5
#
# Epoch 42: val_loss improved from 0.93013 to 0.92321, saving model to iirs3_best.h5
#
# Epoch 43: val_loss improved from 0.92321 to 0.91641, saving model to iirs3_best.h5
#
# Epoch 44: val_loss improved from 0.91641 to 0.90977, saving model to iirs3_best.h5
#
# Epoch 45: val_loss improved from 0.90977 to 0.90330, saving model to iirs3_best.h5
#
# Epoch 46: val_loss improved from 0.90330 to 0.89696, saving model to iirs3_best.h5
#
# Epoch 47: val_loss improved from 0.89696 to 0.89065, saving model to iirs3_best.h5
#
# Epoch 48: val_loss improved from 0.89065 to 0.88443, saving model to iirs3_best.h5
#
# Epoch 49: val_loss improved from 0.88443 to 0.87824, saving model to iirs3_best.h5
#
# Epoch 50: val_loss improved from 0.87824 to 0.87214, saving model to iirs3_best.h5
#
# Epoch 51: val_loss improved from 0.87214 to 0.86615, saving model to iirs3_best.h5
#
# Epoch 52: val_loss improved from 0.86615 to 0.86027, saving model to iirs3_best.h5
#
# Epoch 53: val_loss improved from 0.86027 to 0.85449, saving model to iirs3_best.h5
#
# Epoch 54: val_loss improved from 0.85449 to 0.84882, saving model to iirs3_best.h5
#
# Epoch 55: val_loss improved from 0.84882 to 0.84319, saving model to iirs3_best.h5
#
# Epoch 56: val_loss improved from 0.84319 to 0.83766, saving model to iirs3_best.h5
#
# Epoch 57: val_loss improved from 0.83766 to 0.83222, saving model to iirs3_best.h5
#
# Epoch 58: val_loss improved from 0.83222 to 0.82685, saving model to iirs3_best.h5
#
# Epoch 59: val_loss improved from 0.82685 to 0.82158, saving model to iirs3_best.h5
#
# Epoch 60: val_loss improved from 0.82158 to 0.81640, saving model to iirs3_best.h5
#
# Epoch 61: val_loss improved from 0.81640 to 0.81129, saving model to iirs3_best.h5
#
# Epoch 62: val_loss improved from 0.81129 to 0.80619, saving model to iirs3_best.h5
#
# Epoch 63: val_loss improved from 0.80619 to 0.80116, saving model to iirs3_best.h5
#
# Epoch 64: val_loss improved from 0.80116 to 0.79622, saving model to iirs3_best.h5
#
# Epoch 65: val_loss improved from 0.79622 to 0.79135, saving model to iirs3_best.h5
#
# Epoch 66: val_loss improved from 0.79135 to 0.78657, saving model to iirs3_best.h5
#
# Epoch 67: val_loss improved from 0.78657 to 0.78180, saving model to iirs3_best.h5
#
# Epoch 68: val_loss improved from 0.78180 to 0.77698, saving model to iirs3_best.h5
#
# Epoch 69: val_loss improved from 0.77698 to 0.77216, saving model to iirs3_best.h5
#
# Epoch 70: val_loss improved from 0.77216 to 0.76740, saving model to iirs3_best.h5
#
# Epoch 71: val_loss improved from 0.76740 to 0.76270, saving model to iirs3_best.h5
#
# Epoch 72: val_loss improved from 0.76270 to 0.75803, saving model to iirs3_best.h5
#
# Epoch 73: val_loss improved from 0.75803 to 0.75345, saving model to iirs3_best.h5
#
# Epoch 74: val_loss improved from 0.75345 to 0.74896, saving model to iirs3_best.h5
#
# Epoch 75: val_loss improved from 0.74896 to 0.74456, saving model to iirs3_best.h5
#
# Epoch 76: val_loss improved from 0.74456 to 0.74025, saving model to iirs3_best.h5
#
# Epoch 77: val_loss improved from 0.74025 to 0.73600, saving model to iirs3_best.h5
#
# Epoch 78: val_loss improved from 0.73600 to 0.73181, saving model to iirs3_best.h5
#
# Epoch 79: val_loss improved from 0.73181 to 0.72770, saving model to iirs3_best.h5
#
# Epoch 80: val_loss improved from 0.72770 to 0.72369, saving model to iirs3_best.h5
#
# Epoch 81: val_loss improved from 0.72369 to 0.71977, saving model to iirs3_best.h5
#
# Epoch 82: val_loss improved from 0.71977 to 0.71592, saving model to iirs3_best.h5
#
# Epoch 83: val_loss improved from 0.71592 to 0.71214, saving model to iirs3_best.h5
#
# Epoch 84: val_loss improved from 0.71214 to 0.70844, saving model to iirs3_best.h5
#
# Epoch 85: val_loss improved from 0.70844 to 0.70479, saving model to iirs3_best.h5
#
# Epoch 86: val_loss improved from 0.70479 to 0.70118, saving model to iirs3_best.h5
#
# Epoch 87: val_loss improved from 0.70118 to 0.69762, saving model to iirs3_best.h5
#
# Epoch 88: val_loss improved from 0.69762 to 0.69413, saving model to iirs3_best.h5
#
# Epoch 89: val_loss improved from 0.69413 to 0.69071, saving model to iirs3_best.h5
#
# Epoch 90: val_loss improved from 0.69071 to 0.68735, saving model to iirs3_best.h5
#
# Epoch 91: val_loss improved from 0.68735 to 0.68406, saving model to iirs3_best.h5
#
# Epoch 92: val_loss improved from 0.68406 to 0.68083, saving model to iirs3_best.h5
#
# Epoch 93: val_loss improved from 0.68083 to 0.67767, saving model to iirs3_best.h5
#
# Epoch 94: val_loss improved from 0.67767 to 0.67456, saving model to iirs3_best.h5
#
# Epoch 95: val_loss improved from 0.67456 to 0.67150, saving model to iirs3_best.h5
#
# Epoch 96: val_loss improved from 0.67150 to 0.66850, saving model to iirs3_best.h5
#
# Epoch 97: val_loss improved from 0.66850 to 0.66556, saving model to iirs3_best.h5
#
# Epoch 98: val_loss improved from 0.66556 to 0.66268, saving model to iirs3_best.h5
#
# Epoch 99: val_loss improved from 0.66268 to 0.65983, saving model to iirs3_best.h5
#
# Epoch 100: val_loss improved from 0.65983 to 0.65706, saving model to iirs3_best.h5
#
# Epoch 101: val_loss improved from 0.65706 to 0.65431, saving model to iirs3_best.h5
#
# Epoch 102: val_loss improved from 0.65431 to 0.65162, saving model to iirs3_best.h5
#
# Epoch 103: val_loss improved from 0.65162 to 0.64897, saving model to iirs3_best.h5
#
# Epoch 104: val_loss improved from 0.64897 to 0.64635, saving model to iirs3_best.h5
#
# Epoch 105: val_loss improved from 0.64635 to 0.64377, saving model to iirs3_best.h5
#
# Epoch 106: val_loss improved from 0.64377 to 0.64117, saving model to iirs3_best.h5
#
# Epoch 107: val_loss improved from 0.64117 to 0.63860, saving model to iirs3_best.h5
#
# Epoch 108: val_loss improved from 0.63860 to 0.63607, saving model to iirs3_best.h5
#
# Epoch 109: val_loss improved from 0.63607 to 0.63357, saving model to iirs3_best.h5
#
# Epoch 110: val_loss improved from 0.63357 to 0.63111, saving model to iirs3_best.h5
#
# Epoch 111: val_loss improved from 0.63111 to 0.62868, saving model to iirs3_best.h5
#
# Epoch 112: val_loss improved from 0.62868 to 0.62628, saving model to iirs3_best.h5
#
# Epoch 113: val_loss improved from 0.62628 to 0.62390, saving model to iirs3_best.h5
#
# Epoch 114: val_loss improved from 0.62390 to 0.62159, saving model to iirs3_best.h5
#
# Epoch 115: val_loss improved from 0.62159 to 0.61932, saving model to iirs3_best.h5
#
# Epoch 116: val_loss improved from 0.61932 to 0.61709, saving model to iirs3_best.h5
#
# Epoch 117: val_loss improved from 0.61709 to 0.61488, saving model to iirs3_best.h5
#
# Epoch 118: val_loss improved from 0.61488 to 0.61268, saving model to iirs3_best.h5
#
# Epoch 119: val_loss improved from 0.61268 to 0.61050, saving model to iirs3_best.h5
#
# Epoch 120: val_loss improved from 0.61050 to 0.60833, saving model to iirs3_best.h5
#
# Epoch 121: val_loss improved from 0.60833 to 0.60620, saving model to iirs3_best.h5
#
# Epoch 122: val_loss improved from 0.60620 to 0.60409, saving model to iirs3_best.h5
#
# Epoch 123: val_loss improved from 0.60409 to 0.60201, saving model to iirs3_best.h5
#
# Epoch 124: val_loss improved from 0.60201 to 0.59995, saving model to iirs3_best.h5
#
# Epoch 125: val_loss improved from 0.59995 to 0.59795, saving model to iirs3_best.h5
#
# Epoch 126: val_loss improved from 0.59795 to 0.59597, saving model to iirs3_best.h5
#
# Epoch 127: val_loss improved from 0.59597 to 0.59402, saving model to iirs3_best.h5
#
# Epoch 128: val_loss improved from 0.59402 to 0.59209, saving model to iirs3_best.h5
#
# Epoch 129: val_loss improved from 0.59209 to 0.59019, saving model to iirs3_best.h5
#
# Epoch 130: val_loss improved from 0.59019 to 0.58831, saving model to iirs3_best.h5
#
# Epoch 131: val_loss improved from 0.58831 to 0.58645, saving model to iirs3_best.h5
#
# Epoch 132: val_loss improved from 0.58645 to 0.58460, saving model to iirs3_best.h5
#
# Epoch 133: val_loss improved from 0.58460 to 0.58277, saving model to iirs3_best.h5
#
# Epoch 134: val_loss improved from 0.58277 to 0.58097, saving model to iirs3_best.h5
#
# Epoch 135: val_loss improved from 0.58097 to 0.57919, saving model to iirs3_best.h5
#
# Epoch 136: val_loss improved from 0.57919 to 0.57743, saving model to iirs3_best.h5
#
# Epoch 137: val_loss improved from 0.57743 to 0.57569, saving model to iirs3_best.h5
#
# Epoch 138: val_loss improved from 0.57569 to 0.57396, saving model to iirs3_best.h5
#
# Epoch 139: val_loss improved from 0.57396 to 0.57225, saving model to iirs3_best.h5
#
# Epoch 140: val_loss improved from 0.57225 to 0.57055, saving model to iirs3_best.h5
#
# Epoch 141: val_loss improved from 0.57055 to 0.56888, saving model to iirs3_best.h5
#
# Epoch 142: val_loss improved from 0.56888 to 0.56721, saving model to iirs3_best.h5
#
# Epoch 143: val_loss improved from 0.56721 to 0.56556, saving model to iirs3_best.h5
#
# Epoch 144: val_loss improved from 0.56556 to 0.56392, saving model to iirs3_best.h5
#
# Epoch 145: val_loss improved from 0.56392 to 0.56230, saving model to iirs3_best.h5
#
# Epoch 146: val_loss improved from 0.56230 to 0.56069, saving model to iirs3_best.h5
#
# Epoch 147: val_loss improved from 0.56069 to 0.55910, saving model to iirs3_best.h5
#
# Epoch 148: val_loss improved from 0.55910 to 0.55751, saving model to iirs3_best.h5
#
# Epoch 149: val_loss improved from 0.55751 to 0.55595, saving model to iirs3_best.h5
#
# Epoch 150: val_loss improved from 0.55595 to 0.55439, saving model to iirs3_best.h5
#
# Epoch 151: val_loss improved from 0.55439 to 0.55285, saving model to iirs3_best.h5
#
# Epoch 152: val_loss improved from 0.55285 to 0.55132, saving model to iirs3_best.h5
#
# Epoch 153: val_loss improved from 0.55132 to 0.54980, saving model to iirs3_best.h5
#
# Epoch 154: val_loss improved from 0.54980 to 0.54829, saving model to iirs3_best.h5
#
# Epoch 155: val_loss improved from 0.54829 to 0.54679, saving model to iirs3_best.h5
#
# Epoch 156: val_loss improved from 0.54679 to 0.54531, saving model to iirs3_best.h5
#
# Epoch 157: val_loss improved from 0.54531 to 0.54383, saving model to iirs3_best.h5
#
# Epoch 158: val_loss improved from 0.54383 to 0.54236, saving model to iirs3_best.h5
#
# Epoch 159: val_loss improved from 0.54236 to 0.54090, saving model to iirs3_best.h5
#
# Epoch 160: val_loss improved from 0.54090 to 0.53946, saving model to iirs3_best.h5
#
# Epoch 161: val_loss improved from 0.53946 to 0.53803, saving model to iirs3_best.h5
#
# Epoch 162: val_loss improved from 0.53803 to 0.53661, saving model to iirs3_best.h5
#
# Epoch 163: val_loss improved from 0.53661 to 0.53520, saving model to iirs3_best.h5
#
# Epoch 164: val_loss improved from 0.53520 to 0.53381, saving model to iirs3_best.h5
#
# Epoch 165: val_loss improved from 0.53381 to 0.53242, saving model to iirs3_best.h5
#
# Epoch 166: val_loss improved from 0.53242 to 0.53104, saving model to iirs3_best.h5
#
# Epoch 167: val_loss improved from 0.53104 to 0.52967, saving model to iirs3_best.h5
#
# Epoch 168: val_loss improved from 0.52967 to 0.52831, saving model to iirs3_best.h5
#
# Epoch 169: val_loss improved from 0.52831 to 0.52696, saving model to iirs3_best.h5
#
# Epoch 170: val_loss improved from 0.52696 to 0.52562, saving model to iirs3_best.h5
#
# Epoch 171: val_loss improved from 0.52562 to 0.52428, saving model to iirs3_best.h5
#
# Epoch 172: val_loss improved from 0.52428 to 0.52296, saving model to iirs3_best.h5
#
# Epoch 173: val_loss improved from 0.52296 to 0.52163, saving model to iirs3_best.h5
#
# Epoch 174: val_loss improved from 0.52163 to 0.52032, saving model to iirs3_best.h5
#
# Epoch 175: val_loss improved from 0.52032 to 0.51901, saving model to iirs3_best.h5
#
# Epoch 176: val_loss improved from 0.51901 to 0.51771, saving model to iirs3_best.h5
#
# Epoch 177: val_loss improved from 0.51771 to 0.51641, saving model to iirs3_best.h5
#
# Epoch 178: val_loss improved from 0.51641 to 0.51512, saving model to iirs3_best.h5
#
# Epoch 179: val_loss improved from 0.51512 to 0.51384, saving model to iirs3_best.h5
#
# Epoch 180: val_loss improved from 0.51384 to 0.51256, saving model to iirs3_best.h5
#
# Epoch 181: val_loss improved from 0.51256 to 0.51129, saving model to iirs3_best.h5
#
# Epoch 182: val_loss improved from 0.51129 to 0.51002, saving model to iirs3_best.h5
#
# Epoch 183: val_loss improved from 0.51002 to 0.50875, saving model to iirs3_best.h5
#
# Epoch 184: val_loss improved from 0.50875 to 0.50749, saving model to iirs3_best.h5
#
# Epoch 185: val_loss improved from 0.50749 to 0.50624, saving model to iirs3_best.h5
#
# Epoch 186: val_loss improved from 0.50624 to 0.50499, saving model to iirs3_best.h5
#
# Epoch 187: val_loss improved from 0.50499 to 0.50375, saving model to iirs3_best.h5
#
# Epoch 188: val_loss improved from 0.50375 to 0.50252, saving model to iirs3_best.h5
#
# Epoch 189: val_loss improved from 0.50252 to 0.50129, saving model to iirs3_best.h5
#
# Epoch 190: val_loss improved from 0.50129 to 0.50007, saving model to iirs3_best.h5
#
# Epoch 191: val_loss improved from 0.50007 to 0.49885, saving model to iirs3_best.h5
#
# Epoch 192: val_loss improved from 0.49885 to 0.49764, saving model to iirs3_best.h5
#
# Epoch 193: val_loss improved from 0.49764 to 0.49645, saving model to iirs3_best.h5
#
# Epoch 194: val_loss improved from 0.49645 to 0.49525, saving model to iirs3_best.h5
#
# Epoch 195: val_loss improved from 0.49525 to 0.49406, saving model to iirs3_best.h5
#
# Epoch 196: val_loss improved from 0.49406 to 0.49288, saving model to iirs3_best.h5
#
# Epoch 197: val_loss improved from 0.49288 to 0.49169, saving model to iirs3_best.h5
#
# Epoch 198: val_loss improved from 0.49169 to 0.49051, saving model to iirs3_best.h5
#
# Epoch 199: val_loss improved from 0.49051 to 0.48934, saving model to iirs3_best.h5
#
# Epoch 200: val_loss improved from 0.48934 to 0.48817, saving model to iirs3_best.h5
#
# Epoch 201: val_loss improved from 0.48817 to 0.48700, saving model to iirs3_best.h5
#
# Epoch 202: val_loss improved from 0.48700 to 0.48583, saving model to iirs3_best.h5
#
# Epoch 203: val_loss improved from 0.48583 to 0.48467, saving model to iirs3_best.h5
#
# Epoch 204: val_loss improved from 0.48467 to 0.48351, saving model to iirs3_best.h5
#
# Epoch 205: val_loss improved from 0.48351 to 0.48236, saving model to iirs3_best.h5
#
# Epoch 206: val_loss improved from 0.48236 to 0.48120, saving model to iirs3_best.h5
#
# Epoch 207: val_loss improved from 0.48120 to 0.48006, saving model to iirs3_best.h5
#
# Epoch 208: val_loss improved from 0.48006 to 0.47891, saving model to iirs3_best.h5
#
# Epoch 209: val_loss improved from 0.47891 to 0.47777, saving model to iirs3_best.h5
#
# Epoch 210: val_loss improved from 0.47777 to 0.47664, saving model to iirs3_best.h5
#
# Epoch 211: val_loss improved from 0.47664 to 0.47551, saving model to iirs3_best.h5
#
# Epoch 212: val_loss improved from 0.47551 to 0.47438, saving model to iirs3_best.h5
#
# Epoch 213: val_loss improved from 0.47438 to 0.47325, saving model to iirs3_best.h5
#
# Epoch 214: val_loss improved from 0.47325 to 0.47212, saving model to iirs3_best.h5
#
# Epoch 215: val_loss improved from 0.47212 to 0.47100, saving model to iirs3_best.h5
#
# Epoch 216: val_loss improved from 0.47100 to 0.46988, saving model to iirs3_best.h5
#
# Epoch 217: val_loss improved from 0.46988 to 0.46876, saving model to iirs3_best.h5
#
# Epoch 218: val_loss improved from 0.46876 to 0.46765, saving model to iirs3_best.h5
#
# Epoch 219: val_loss improved from 0.46765 to 0.46653, saving model to iirs3_best.h5
#
# Epoch 220: val_loss improved from 0.46653 to 0.46542, saving model to iirs3_best.h5
#
# Epoch 221: val_loss improved from 0.46542 to 0.46430, saving model to iirs3_best.h5
#
# Epoch 222: val_loss improved from 0.46430 to 0.46319, saving model to iirs3_best.h5
#
# Epoch 223: val_loss improved from 0.46319 to 0.46208, saving model to iirs3_best.h5
#
# Epoch 224: val_loss improved from 0.46208 to 0.46096, saving model to iirs3_best.h5
#
# Epoch 225: val_loss improved from 0.46096 to 0.45983, saving model to iirs3_best.h5
#
# Epoch 226: val_loss improved from 0.45983 to 0.45871, saving model to iirs3_best.h5
#
# Epoch 227: val_loss improved from 0.45871 to 0.45758, saving model to iirs3_best.h5
#
# Epoch 228: val_loss improved from 0.45758 to 0.45647, saving model to iirs3_best.h5
#
# Epoch 229: val_loss improved from 0.45647 to 0.45535, saving model to iirs3_best.h5
#
# Epoch 230: val_loss improved from 0.45535 to 0.45424, saving model to iirs3_best.h5
#
# Epoch 231: val_loss improved from 0.45424 to 0.45314, saving model to iirs3_best.h5
#
# Epoch 232: val_loss improved from 0.45314 to 0.45204, saving model to iirs3_best.h5
#
# Epoch 233: val_loss improved from 0.45204 to 0.45095, saving model to iirs3_best.h5
#
# Epoch 234: val_loss improved from 0.45095 to 0.44986, saving model to iirs3_best.h5
#
# Epoch 235: val_loss improved from 0.44986 to 0.44876, saving model to iirs3_best.h5
#
# Epoch 236: val_loss improved from 0.44876 to 0.44767, saving model to iirs3_best.h5
#
# Epoch 237: val_loss improved from 0.44767 to 0.44658, saving model to iirs3_best.h5
#
# Epoch 238: val_loss improved from 0.44658 to 0.44550, saving model to iirs3_best.h5
#
# Epoch 239: val_loss improved from 0.44550 to 0.44441, saving model to iirs3_best.h5
#
# Epoch 240: val_loss improved from 0.44441 to 0.44333, saving model to iirs3_best.h5
#
# Epoch 241: val_loss improved from 0.44333 to 0.44224, saving model to iirs3_best.h5
#
# Epoch 242: val_loss improved from 0.44224 to 0.44116, saving model to iirs3_best.h5
#
# Epoch 243: val_loss improved from 0.44116 to 0.44008, saving model to iirs3_best.h5
#
# Epoch 244: val_loss improved from 0.44008 to 0.43899, saving model to iirs3_best.h5
#
# Epoch 245: val_loss improved from 0.43899 to 0.43790, saving model to iirs3_best.h5
#
# Epoch 246: val_loss improved from 0.43790 to 0.43681, saving model to iirs3_best.h5
#
# Epoch 247: val_loss improved from 0.43681 to 0.43572, saving model to iirs3_best.h5
#
# Epoch 248: val_loss improved from 0.43572 to 0.43462, saving model to iirs3_best.h5
#
# Epoch 249: val_loss improved from 0.43462 to 0.43352, saving model to iirs3_best.h5
#
# Epoch 250: val_loss improved from 0.43352 to 0.43242, saving model to iirs3_best.h5
#
# Epoch 251: val_loss improved from 0.43242 to 0.43132, saving model to iirs3_best.h5
#
# Epoch 252: val_loss improved from 0.43132 to 0.43022, saving model to iirs3_best.h5
#
# Epoch 253: val_loss improved from 0.43022 to 0.42912, saving model to iirs3_best.h5
#
# Epoch 254: val_loss improved from 0.42912 to 0.42802, saving model to iirs3_best.h5
#
# Epoch 255: val_loss improved from 0.42802 to 0.42689, saving model to iirs3_best.h5
#
# Epoch 256: val_loss improved from 0.42689 to 0.42574, saving model to iirs3_best.h5
#
# Epoch 257: val_loss improved from 0.42574 to 0.42458, saving model to iirs3_best.h5
#
# Epoch 258: val_loss improved from 0.42458 to 0.42339, saving model to iirs3_best.h5
#
# Epoch 259: val_loss improved from 0.42339 to 0.42219, saving model to iirs3_best.h5
#
# Epoch 260: val_loss improved from 0.42219 to 0.42099, saving model to iirs3_best.h5
#
# Epoch 261: val_loss improved from 0.42099 to 0.41979, saving model to iirs3_best.h5
#
# Epoch 262: val_loss improved from 0.41979 to 0.41859, saving model to iirs3_best.h5
#
# Epoch 263: val_loss improved from 0.41859 to 0.41738, saving model to iirs3_best.h5
#
# Epoch 264: val_loss improved from 0.41738 to 0.41619, saving model to iirs3_best.h5
#
# Epoch 265: val_loss improved from 0.41619 to 0.41500, saving model to iirs3_best.h5
#
# Epoch 266: val_loss improved from 0.41500 to 0.41382, saving model to iirs3_best.h5
#
# Epoch 267: val_loss improved from 0.41382 to 0.41265, saving model to iirs3_best.h5
#
# Epoch 268: val_loss improved from 0.41265 to 0.41149, saving model to iirs3_best.h5
#
# Epoch 269: val_loss improved from 0.41149 to 0.41033, saving model to iirs3_best.h5
#
# Epoch 270: val_loss improved from 0.41033 to 0.40920, saving model to iirs3_best.h5
#
# Epoch 271: val_loss improved from 0.40920 to 0.40807, saving model to iirs3_best.h5
#
# Epoch 272: val_loss improved from 0.40807 to 0.40693, saving model to iirs3_best.h5
#
# Epoch 273: val_loss improved from 0.40693 to 0.40579, saving model to iirs3_best.h5
#
# Epoch 274: val_loss improved from 0.40579 to 0.40465, saving model to iirs3_best.h5
#
# Epoch 275: val_loss improved from 0.40465 to 0.40350, saving model to iirs3_best.h5
#
# Epoch 276: val_loss improved from 0.40350 to 0.40230, saving model to iirs3_best.h5
#
# Epoch 277: val_loss improved from 0.40230 to 0.40105, saving model to iirs3_best.h5
#
# Epoch 278: val_loss improved from 0.40105 to 0.39979, saving model to iirs3_best.h5
#
# Epoch 279: val_loss improved from 0.39979 to 0.39854, saving model to iirs3_best.h5
#
# Epoch 280: val_loss improved from 0.39854 to 0.39728, saving model to iirs3_best.h5
#
# Epoch 281: val_loss improved from 0.39728 to 0.39603, saving model to iirs3_best.h5
#
# Epoch 282: val_loss improved from 0.39603 to 0.39477, saving model to iirs3_best.h5
#
# Epoch 283: val_loss improved from 0.39477 to 0.39352, saving model to iirs3_best.h5
#
# Epoch 284: val_loss improved from 0.39352 to 0.39227, saving model to iirs3_best.h5
#
# Epoch 285: val_loss improved from 0.39227 to 0.39111, saving model to iirs3_best.h5
#
# Epoch 286: val_loss improved from 0.39111 to 0.38997, saving model to iirs3_best.h5
#
# Epoch 287: val_loss improved from 0.38997 to 0.38884, saving model to iirs3_best.h5
#
# Epoch 288: val_loss improved from 0.38884 to 0.38771, saving model to iirs3_best.h5
#
# Epoch 289: val_loss improved from 0.38771 to 0.38655, saving model to iirs3_best.h5
#
# Epoch 290: val_loss improved from 0.38655 to 0.38541, saving model to iirs3_best.h5
#
# Epoch 291: val_loss improved from 0.38541 to 0.38428, saving model to iirs3_best.h5
#
# Epoch 292: val_loss improved from 0.38428 to 0.38315, saving model to iirs3_best.h5
#
# Epoch 293: val_loss improved from 0.38315 to 0.38201, saving model to iirs3_best.h5
#
# Epoch 294: val_loss improved from 0.38201 to 0.38085, saving model to iirs3_best.h5
#
# Epoch 295: val_loss improved from 0.38085 to 0.37971, saving model to iirs3_best.h5
#
# Epoch 296: val_loss improved from 0.37971 to 0.37852, saving model to iirs3_best.h5
#
# Epoch 297: val_loss improved from 0.37852 to 0.37733, saving model to iirs3_best.h5
#
# Epoch 298: val_loss improved from 0.37733 to 0.37615, saving model to iirs3_best.h5
#
# Epoch 299: val_loss improved from 0.37615 to 0.37497, saving model to iirs3_best.h5
#
# Epoch 300: val_loss improved from 0.37497 to 0.37376, saving model to iirs3_best.h5
#
# Epoch 301: val_loss improved from 0.37376 to 0.37257, saving model to iirs3_best.h5
#
# Epoch 302: val_loss improved from 0.37257 to 0.37138, saving model to iirs3_best.h5
#
# Epoch 303: val_loss improved from 0.37138 to 0.37019, saving model to iirs3_best.h5
#
# Epoch 304: val_loss improved from 0.37019 to 0.36897, saving model to iirs3_best.h5
#
# Epoch 305: val_loss improved from 0.36897 to 0.36775, saving model to iirs3_best.h5
#
# Epoch 306: val_loss improved from 0.36775 to 0.36653, saving model to iirs3_best.h5
#
# Epoch 307: val_loss improved from 0.36653 to 0.36529, saving model to iirs3_best.h5
#
# Epoch 308: val_loss improved from 0.36529 to 0.36405, saving model to iirs3_best.h5
#
# Epoch 309: val_loss improved from 0.36405 to 0.36280, saving model to iirs3_best.h5
#
# Epoch 310: val_loss improved from 0.36280 to 0.36155, saving model to iirs3_best.h5
#
# Epoch 311: val_loss improved from 0.36155 to 0.36030, saving model to iirs3_best.h5
#
# Epoch 312: val_loss improved from 0.36030 to 0.35904, saving model to iirs3_best.h5
#
# Epoch 313: val_loss improved from 0.35904 to 0.35772, saving model to iirs3_best.h5
#
# Epoch 314: val_loss improved from 0.35772 to 0.35636, saving model to iirs3_best.h5
#
# Epoch 315: val_loss improved from 0.35636 to 0.35498, saving model to iirs3_best.h5
#
# Epoch 316: val_loss improved from 0.35498 to 0.35360, saving model to iirs3_best.h5
#
# Epoch 317: val_loss improved from 0.35360 to 0.35223, saving model to iirs3_best.h5
#
# Epoch 318: val_loss improved from 0.35223 to 0.35090, saving model to iirs3_best.h5
#
# Epoch 319: val_loss improved from 0.35090 to 0.34966, saving model to iirs3_best.h5
#
# Epoch 320: val_loss improved from 0.34966 to 0.34844, saving model to iirs3_best.h5
#
# Epoch 321: val_loss improved from 0.34844 to 0.34723, saving model to iirs3_best.h5
#
# Epoch 322: val_loss improved from 0.34723 to 0.34602, saving model to iirs3_best.h5
#
# Epoch 323: val_loss improved from 0.34602 to 0.34482, saving model to iirs3_best.h5
#
# Epoch 324: val_loss improved from 0.34482 to 0.34363, saving model to iirs3_best.h5
#
# Epoch 325: val_loss improved from 0.34363 to 0.34245, saving model to iirs3_best.h5
#
# Epoch 326: val_loss improved from 0.34245 to 0.34128, saving model to iirs3_best.h5
#
# Epoch 327: val_loss improved from 0.34128 to 0.34011, saving model to iirs3_best.h5
#
# Epoch 328: val_loss improved from 0.34011 to 0.33895, saving model to iirs3_best.h5
#
# Epoch 329: val_loss improved from 0.33895 to 0.33779, saving model to iirs3_best.h5
#
# Epoch 330: val_loss improved from 0.33779 to 0.33662, saving model to iirs3_best.h5
#
# Epoch 331: val_loss improved from 0.33662 to 0.33540, saving model to iirs3_best.h5
#
# Epoch 332: val_loss improved from 0.33540 to 0.33413, saving model to iirs3_best.h5
#
# Epoch 333: val_loss improved from 0.33413 to 0.33284, saving model to iirs3_best.h5
#
# Epoch 334: val_loss improved from 0.33284 to 0.33153, saving model to iirs3_best.h5
#
# Epoch 335: val_loss improved from 0.33153 to 0.33015, saving model to iirs3_best.h5
#
# Epoch 336: val_loss improved from 0.33015 to 0.32883, saving model to iirs3_best.h5
#
# Epoch 337: val_loss improved from 0.32883 to 0.32754, saving model to iirs3_best.h5
#
# Epoch 338: val_loss improved from 0.32754 to 0.32622, saving model to iirs3_best.h5
#
# Epoch 339: val_loss improved from 0.32622 to 0.32483, saving model to iirs3_best.h5
#
# Epoch 340: val_loss improved from 0.32483 to 0.32340, saving model to iirs3_best.h5
#
# Epoch 341: val_loss improved from 0.32340 to 0.32191, saving model to iirs3_best.h5
#
# Epoch 342: val_loss improved from 0.32191 to 0.32042, saving model to iirs3_best.h5
#
# Epoch 343: val_loss improved from 0.32042 to 0.31892, saving model to iirs3_best.h5
#
# Epoch 344: val_loss improved from 0.31892 to 0.31743, saving model to iirs3_best.h5
#
# Epoch 345: val_loss improved from 0.31743 to 0.31602, saving model to iirs3_best.h5
#
# Epoch 346: val_loss improved from 0.31602 to 0.31454, saving model to iirs3_best.h5
#
# Epoch 347: val_loss improved from 0.31454 to 0.31279, saving model to iirs3_best.h5
#
# Epoch 348: val_loss improved from 0.31279 to 0.31121, saving model to iirs3_best.h5
#
# Epoch 349: val_loss improved from 0.31121 to 0.30979, saving model to iirs3_best.h5
#
# Epoch 350: val_loss improved from 0.30979 to 0.30839, saving model to iirs3_best.h5
#
# Epoch 351: val_loss improved from 0.30839 to 0.30703, saving model to iirs3_best.h5
#
# Epoch 352: val_loss improved from 0.30703 to 0.30567, saving model to iirs3_best.h5
#
# Epoch 353: val_loss improved from 0.30567 to 0.30434, saving model to iirs3_best.h5
#
# Epoch 354: val_loss improved from 0.30434 to 0.30303, saving model to iirs3_best.h5
#
# Epoch 355: val_loss improved from 0.30303 to 0.30173, saving model to iirs3_best.h5
#
# Epoch 356: val_loss improved from 0.30173 to 0.30030, saving model to iirs3_best.h5
#
# Epoch 357: val_loss improved from 0.30030 to 0.29875, saving model to iirs3_best.h5
#
# Epoch 358: val_loss improved from 0.29875 to 0.29719, saving model to iirs3_best.h5
#
# Epoch 359: val_loss improved from 0.29719 to 0.29658, saving model to iirs3_best.h5
#
# Epoch 360: val_loss improved from 0.29658 to 0.29617, saving model to iirs3_best.h5
#
# Epoch 361: val_loss improved from 0.29617 to 0.29549, saving model to iirs3_best.h5
#
# Epoch 362: val_loss improved from 0.29549 to 0.29476, saving model to iirs3_best.h5
#
# Epoch 363: val_loss improved from 0.29476 to 0.29397, saving model to iirs3_best.h5
#
# Epoch 364: val_loss improved from 0.29397 to 0.29319, saving model to iirs3_best.h5
#
# Epoch 365: val_loss improved from 0.29319 to 0.29226, saving model to iirs3_best.h5
#
# Epoch 366: val_loss improved from 0.29226 to 0.29117, saving model to iirs3_best.h5
#
# Epoch 367: val_loss improved from 0.29117 to 0.28990, saving model to iirs3_best.h5
#
# Epoch 368: val_loss improved from 0.28990 to 0.28841, saving model to iirs3_best.h5
#
# Epoch 369: val_loss improved from 0.28841 to 0.28677, saving model to iirs3_best.h5
#
# Epoch 370: val_loss improved from 0.28677 to 0.28500, saving model to iirs3_best.h5
#
# Epoch 371: val_loss improved from 0.28500 to 0.28316, saving model to iirs3_best.h5
#
# Epoch 372: val_loss improved from 0.28316 to 0.28122, saving model to iirs3_best.h5
#
# Epoch 373: val_loss improved from 0.28122 to 0.27920, saving model to iirs3_best.h5
#
# Epoch 374: val_loss improved from 0.27920 to 0.27714, saving model to iirs3_best.h5
#
# Epoch 375: val_loss improved from 0.27714 to 0.27506, saving model to iirs3_best.h5
#
# Epoch 376: val_loss improved from 0.27506 to 0.27297, saving model to iirs3_best.h5
#
# Epoch 377: val_loss improved from 0.27297 to 0.27076, saving model to iirs3_best.h5
#
# Epoch 378: val_loss improved from 0.27076 to 0.26844, saving model to iirs3_best.h5
#
# Epoch 379: val_loss improved from 0.26844 to 0.26601, saving model to iirs3_best.h5
#
# Epoch 380: val_loss improved from 0.26601 to 0.26353, saving model to iirs3_best.h5
#
# Epoch 381: val_loss improved from 0.26353 to 0.26101, saving model to iirs3_best.h5
#
# Epoch 382: val_loss improved from 0.26101 to 0.25848, saving model to iirs3_best.h5
#
# Epoch 383: val_loss improved from 0.25848 to 0.25604, saving model to iirs3_best.h5
#
# Epoch 384: val_loss improved from 0.25604 to 0.25390, saving model to iirs3_best.h5
#
# Epoch 385: val_loss improved from 0.25390 to 0.25178, saving model to iirs3_best.h5
#
# Epoch 386: val_loss improved from 0.25178 to 0.24968, saving model to iirs3_best.h5
#
# Epoch 387: val_loss improved from 0.24968 to 0.24762, saving model to iirs3_best.h5
#
# Epoch 388: val_loss improved from 0.24762 to 0.24560, saving model to iirs3_best.h5
#
# Epoch 389: val_loss improved from 0.24560 to 0.24363, saving model to iirs3_best.h5
#
# Epoch 390: val_loss improved from 0.24363 to 0.24172, saving model to iirs3_best.h5
#
# Epoch 391: val_loss improved from 0.24172 to 0.23987, saving model to iirs3_best.h5
#
# Epoch 392: val_loss improved from 0.23987 to 0.23807, saving model to iirs3_best.h5
#
# Epoch 393: val_loss improved from 0.23807 to 0.23632, saving model to iirs3_best.h5
#
# Epoch 394: val_loss improved from 0.23632 to 0.23462, saving model to iirs3_best.h5
#
# Epoch 395: val_loss improved from 0.23462 to 0.23296, saving model to iirs3_best.h5
#
# Epoch 396: val_loss improved from 0.23296 to 0.23133, saving model to iirs3_best.h5
#
# Epoch 397: val_loss improved from 0.23133 to 0.23003, saving model to iirs3_best.h5
#
# Epoch 398: val_loss improved from 0.23003 to 0.22884, saving model to iirs3_best.h5
#
# Epoch 399: val_loss improved from 0.22884 to 0.22768, saving model to iirs3_best.h5
#
# Epoch 400: val_loss improved from 0.22768 to 0.22656, saving model to iirs3_best.h5
#
# Epoch 401: val_loss improved from 0.22656 to 0.22546, saving model to iirs3_best.h5
#
# Epoch 402: val_loss improved from 0.22546 to 0.22439, saving model to iirs3_best.h5
#
# Epoch 403: val_loss improved from 0.22439 to 0.22331, saving model to iirs3_best.h5
#
# Epoch 404: val_loss improved from 0.22331 to 0.22224, saving model to iirs3_best.h5
#
# Epoch 405: val_loss improved from 0.22224 to 0.22115, saving model to iirs3_best.h5
#
# Epoch 406: val_loss improved from 0.22115 to 0.22005, saving model to iirs3_best.h5
#
# Epoch 407: val_loss improved from 0.22005 to 0.21893, saving model to iirs3_best.h5
#
# Epoch 408: val_loss improved from 0.21893 to 0.21778, saving model to iirs3_best.h5
#
# Epoch 409: val_loss improved from 0.21778 to 0.21662, saving model to iirs3_best.h5
#
# Epoch 410: val_loss improved from 0.21662 to 0.21547, saving model to iirs3_best.h5
#
# Epoch 411: val_loss improved from 0.21547 to 0.21415, saving model to iirs3_best.h5
#
# Epoch 412: val_loss improved from 0.21415 to 0.21278, saving model to iirs3_best.h5
#
# Epoch 413: val_loss improved from 0.21278 to 0.21138, saving model to iirs3_best.h5
#
# Epoch 414: val_loss improved from 0.21138 to 0.20997, saving model to iirs3_best.h5
#
# Epoch 415: val_loss improved from 0.20997 to 0.20857, saving model to iirs3_best.h5
#
# Epoch 416: val_loss improved from 0.20857 to 0.20717, saving model to iirs3_best.h5
#
# Epoch 417: val_loss improved from 0.20717 to 0.20582, saving model to iirs3_best.h5
#
# Epoch 418: val_loss improved from 0.20582 to 0.20449, saving model to iirs3_best.h5
#
# Epoch 419: val_loss improved from 0.20449 to 0.20321, saving model to iirs3_best.h5
#
# Epoch 420: val_loss improved from 0.20321 to 0.20196, saving model to iirs3_best.h5
#
# Epoch 421: val_loss improved from 0.20196 to 0.20077, saving model to iirs3_best.h5
#
# Epoch 422: val_loss improved from 0.20077 to 0.19960, saving model to iirs3_best.h5
#
# Epoch 423: val_loss improved from 0.19960 to 0.19842, saving model to iirs3_best.h5
#
# Epoch 424: val_loss improved from 0.19842 to 0.19725, saving model to iirs3_best.h5
#
# Epoch 425: val_loss improved from 0.19725 to 0.19609, saving model to iirs3_best.h5
#
# Epoch 426: val_loss improved from 0.19609 to 0.19494, saving model to iirs3_best.h5
#
# Epoch 427: val_loss improved from 0.19494 to 0.19379, saving model to iirs3_best.h5
#
# Epoch 428: val_loss improved from 0.19379 to 0.19265, saving model to iirs3_best.h5
#
# Epoch 429: val_loss improved from 0.19265 to 0.19152, saving model to iirs3_best.h5
#
# Epoch 430: val_loss improved from 0.19152 to 0.19040, saving model to iirs3_best.h5
#
# Epoch 431: val_loss improved from 0.19040 to 0.18930, saving model to iirs3_best.h5
#
# Epoch 432: val_loss improved from 0.18930 to 0.18821, saving model to iirs3_best.h5
#
# Epoch 433: val_loss improved from 0.18821 to 0.18715, saving model to iirs3_best.h5
#
# Epoch 434: val_loss improved from 0.18715 to 0.18610, saving model to iirs3_best.h5
#
# Epoch 435: val_loss improved from 0.18610 to 0.18504, saving model to iirs3_best.h5
#
# Epoch 436: val_loss improved from 0.18504 to 0.18392, saving model to iirs3_best.h5
#
# Epoch 437: val_loss improved from 0.18392 to 0.18276, saving model to iirs3_best.h5
#
# Epoch 438: val_loss improved from 0.18276 to 0.18158, saving model to iirs3_best.h5
#
# Epoch 439: val_loss improved from 0.18158 to 0.18039, saving model to iirs3_best.h5
#
# Epoch 440: val_loss improved from 0.18039 to 0.17919, saving model to iirs3_best.h5
#
# Epoch 441: val_loss improved from 0.17919 to 0.17798, saving model to iirs3_best.h5
#
# Epoch 442: val_loss improved from 0.17798 to 0.17676, saving model to iirs3_best.h5
#
# Epoch 443: val_loss improved from 0.17676 to 0.17553, saving model to iirs3_best.h5
#
# Epoch 444: val_loss improved from 0.17553 to 0.17430, saving model to iirs3_best.h5
#
# Epoch 445: val_loss improved from 0.17430 to 0.17307, saving model to iirs3_best.h5
#
# Epoch 446: val_loss improved from 0.17307 to 0.17183, saving model to iirs3_best.h5
#
# Epoch 447: val_loss improved from 0.17183 to 0.17060, saving model to iirs3_best.h5
#
# Epoch 448: val_loss improved from 0.17060 to 0.16935, saving model to iirs3_best.h5
#
# Epoch 449: val_loss improved from 0.16935 to 0.16810, saving model to iirs3_best.h5
#
# Epoch 450: val_loss improved from 0.16810 to 0.16685, saving model to iirs3_best.h5
#
# Epoch 451: val_loss improved from 0.16685 to 0.16559, saving model to iirs3_best.h5
#
# Epoch 452: val_loss improved from 0.16559 to 0.16434, saving model to iirs3_best.h5
#
# Epoch 453: val_loss improved from 0.16434 to 0.16309, saving model to iirs3_best.h5
#
# Epoch 454: val_loss improved from 0.16309 to 0.16185, saving model to iirs3_best.h5
#
# Epoch 455: val_loss improved from 0.16185 to 0.16061, saving model to iirs3_best.h5
#
# Epoch 456: val_loss improved from 0.16061 to 0.15938, saving model to iirs3_best.h5
#
# Epoch 457: val_loss improved from 0.15938 to 0.15816, saving model to iirs3_best.h5
#
# Epoch 458: val_loss improved from 0.15816 to 0.15696, saving model to iirs3_best.h5
#
# Epoch 459: val_loss improved from 0.15696 to 0.15578, saving model to iirs3_best.h5
#
# Epoch 460: val_loss improved from 0.15578 to 0.15461, saving model to iirs3_best.h5
#
# Epoch 461: val_loss improved from 0.15461 to 0.15345, saving model to iirs3_best.h5
#
# Epoch 462: val_loss improved from 0.15345 to 0.15232, saving model to iirs3_best.h5
#
# Epoch 463: val_loss improved from 0.15232 to 0.15119, saving model to iirs3_best.h5
#
# Epoch 464: val_loss improved from 0.15119 to 0.15008, saving model to iirs3_best.h5
#
# Epoch 465: val_loss improved from 0.15008 to 0.14896, saving model to iirs3_best.h5
#
# Epoch 466: val_loss improved from 0.14896 to 0.14785, saving model to iirs3_best.h5
#
# Epoch 467: val_loss improved from 0.14785 to 0.14673, saving model to iirs3_best.h5
#
# Epoch 468: val_loss improved from 0.14673 to 0.14562, saving model to iirs3_best.h5
#
# Epoch 469: val_loss improved from 0.14562 to 0.14452, saving model to iirs3_best.h5
#
# Epoch 470: val_loss improved from 0.14452 to 0.14343, saving model to iirs3_best.h5
#
# Epoch 471: val_loss improved from 0.14343 to 0.14235, saving model to iirs3_best.h5
#
# Epoch 472: val_loss improved from 0.14235 to 0.14127, saving model to iirs3_best.h5
#
# Epoch 473: val_loss improved from 0.14127 to 0.14020, saving model to iirs3_best.h5
#
# Epoch 474: val_loss improved from 0.14020 to 0.13913, saving model to iirs3_best.h5
#
# Epoch 475: val_loss improved from 0.13913 to 0.13807, saving model to iirs3_best.h5
#
# Epoch 476: val_loss improved from 0.13807 to 0.13702, saving model to iirs3_best.h5
#
# Epoch 477: val_loss improved from 0.13702 to 0.13598, saving model to iirs3_best.h5
#
# Epoch 478: val_loss improved from 0.13598 to 0.13495, saving model to iirs3_best.h5
#
# Epoch 479: val_loss improved from 0.13495 to 0.13393, saving model to iirs3_best.h5
#
# Epoch 480: val_loss improved from 0.13393 to 0.13292, saving model to iirs3_best.h5
#
# Epoch 481: val_loss improved from 0.13292 to 0.13192, saving model to iirs3_best.h5
#
# Epoch 482: val_loss improved from 0.13192 to 0.13094, saving model to iirs3_best.h5
#
# Epoch 483: val_loss improved from 0.13094 to 0.12998, saving model to iirs3_best.h5
#
# Epoch 484: val_loss improved from 0.12998 to 0.12905, saving model to iirs3_best.h5
#
# Epoch 485: val_loss improved from 0.12905 to 0.12814, saving model to iirs3_best.h5
#
# Epoch 486: val_loss improved from 0.12814 to 0.12724, saving model to iirs3_best.h5
#
# Epoch 487: val_loss improved from 0.12724 to 0.12635, saving model to iirs3_best.h5
#
# Epoch 488: val_loss improved from 0.12635 to 0.12547, saving model to iirs3_best.h5
#
# Epoch 489: val_loss improved from 0.12547 to 0.12460, saving model to iirs3_best.h5
#
# Epoch 490: val_loss improved from 0.12460 to 0.12374, saving model to iirs3_best.h5
#
# Epoch 491: val_loss improved from 0.12374 to 0.12289, saving model to iirs3_best.h5
#
# Epoch 492: val_loss improved from 0.12289 to 0.12205, saving model to iirs3_best.h5
#
# Epoch 493: val_loss improved from 0.12205 to 0.12122, saving model to iirs3_best.h5
#
# Epoch 494: val_loss improved from 0.12122 to 0.12041, saving model to iirs3_best.h5
#
# Epoch 495: val_loss improved from 0.12041 to 0.11961, saving model to iirs3_best.h5
#
# Epoch 496: val_loss improved from 0.11961 to 0.11883, saving model to iirs3_best.h5
#
# Epoch 497: val_loss improved from 0.11883 to 0.11805, saving model to iirs3_best.h5
#
# Epoch 498: val_loss improved from 0.11805 to 0.11730, saving model to iirs3_best.h5
#
# Epoch 499: val_loss improved from 0.11730 to 0.11655, saving model to iirs3_best.h5
#
# Epoch 500: val_loss improved from 0.11655 to 0.11581, saving model to iirs3_best.h5
#
# Epoch 501: val_loss improved from 0.11581 to 0.11508, saving model to iirs3_best.h5
#
# Epoch 502: val_loss improved from 0.11508 to 0.11435, saving model to iirs3_best.h5
#
# Epoch 503: val_loss improved from 0.11435 to 0.11364, saving model to iirs3_best.h5
#
# Epoch 504: val_loss improved from 0.11364 to 0.11293, saving model to iirs3_best.h5
#
# Epoch 505: val_loss improved from 0.11293 to 0.11221, saving model to iirs3_best.h5
#
# Epoch 506: val_loss improved from 0.11221 to 0.11150, saving model to iirs3_best.h5
#
# Epoch 507: val_loss improved from 0.11150 to 0.11082, saving model to iirs3_best.h5
#
# Epoch 508: val_loss improved from 0.11082 to 0.11016, saving model to iirs3_best.h5
#
# Epoch 509: val_loss improved from 0.11016 to 0.10952, saving model to iirs3_best.h5
#
# Epoch 510: val_loss improved from 0.10952 to 0.10890, saving model to iirs3_best.h5
#
# Epoch 511: val_loss improved from 0.10890 to 0.10829, saving model to iirs3_best.h5
#
# Epoch 512: val_loss improved from 0.10829 to 0.10769, saving model to iirs3_best.h5
#
# Epoch 513: val_loss improved from 0.10769 to 0.10711, saving model to iirs3_best.h5
#
# Epoch 514: val_loss improved from 0.10711 to 0.10652, saving model to iirs3_best.h5
#
# Epoch 515: val_loss improved from 0.10652 to 0.10595, saving model to iirs3_best.h5
#
# Epoch 516: val_loss improved from 0.10595 to 0.10538, saving model to iirs3_best.h5
#
# Epoch 517: val_loss improved from 0.10538 to 0.10481, saving model to iirs3_best.h5
#
# Epoch 518: val_loss improved from 0.10481 to 0.10425, saving model to iirs3_best.h5
#
# Epoch 519: val_loss improved from 0.10425 to 0.10369, saving model to iirs3_best.h5
#
# Epoch 520: val_loss improved from 0.10369 to 0.10314, saving model to iirs3_best.h5
#
# Epoch 521: val_loss improved from 0.10314 to 0.10260, saving model to iirs3_best.h5
#
# Epoch 522: val_loss improved from 0.10260 to 0.10206, saving model to iirs3_best.h5
#
# Epoch 523: val_loss improved from 0.10206 to 0.10153, saving model to iirs3_best.h5
#
# Epoch 524: val_loss improved from 0.10153 to 0.10099, saving model to iirs3_best.h5
#
# Epoch 525: val_loss improved from 0.10099 to 0.10046, saving model to iirs3_best.h5
#
# Epoch 526: val_loss improved from 0.10046 to 0.09994, saving model to iirs3_best.h5
#
# Epoch 527: val_loss improved from 0.09994 to 0.09942, saving model to iirs3_best.h5
#
# Epoch 528: val_loss improved from 0.09942 to 0.09890, saving model to iirs3_best.h5
#
# Epoch 529: val_loss improved from 0.09890 to 0.09839, saving model to iirs3_best.h5
#
# Epoch 530: val_loss improved from 0.09839 to 0.09789, saving model to iirs3_best.h5
#
# Epoch 531: val_loss improved from 0.09789 to 0.09739, saving model to iirs3_best.h5
#
# Epoch 532: val_loss improved from 0.09739 to 0.09690, saving model to iirs3_best.h5
#
# Epoch 533: val_loss improved from 0.09690 to 0.09641, saving model to iirs3_best.h5
#
# Epoch 534: val_loss improved from 0.09641 to 0.09593, saving model to iirs3_best.h5
#
# Epoch 535: val_loss improved from 0.09593 to 0.09546, saving model to iirs3_best.h5
#
# Epoch 536: val_loss improved from 0.09546 to 0.09498, saving model to iirs3_best.h5
#
# Epoch 537: val_loss improved from 0.09498 to 0.09451, saving model to iirs3_best.h5
#
# Epoch 538: val_loss improved from 0.09451 to 0.09405, saving model to iirs3_best.h5
#
# Epoch 539: val_loss improved from 0.09405 to 0.09359, saving model to iirs3_best.h5
#
# Epoch 540: val_loss improved from 0.09359 to 0.09312, saving model to iirs3_best.h5
#
# Epoch 541: val_loss improved from 0.09312 to 0.09267, saving model to iirs3_best.h5
#
# Epoch 542: val_loss improved from 0.09267 to 0.09221, saving model to iirs3_best.h5
#
# Epoch 543: val_loss improved from 0.09221 to 0.09176, saving model to iirs3_best.h5
#
# Epoch 544: val_loss improved from 0.09176 to 0.09131, saving model to iirs3_best.h5
#
# Epoch 545: val_loss improved from 0.09131 to 0.09086, saving model to iirs3_best.h5
#
# Epoch 546: val_loss improved from 0.09086 to 0.09042, saving model to iirs3_best.h5
#
# Epoch 547: val_loss improved from 0.09042 to 0.08998, saving model to iirs3_best.h5
#
# Epoch 548: val_loss improved from 0.08998 to 0.08954, saving model to iirs3_best.h5
#
# Epoch 549: val_loss improved from 0.08954 to 0.08910, saving model to iirs3_best.h5
#
# Epoch 550: val_loss improved from 0.08910 to 0.08867, saving model to iirs3_best.h5
#
# Epoch 551: val_loss improved from 0.08867 to 0.08824, saving model to iirs3_best.h5
#
# Epoch 552: val_loss improved from 0.08824 to 0.08782, saving model to iirs3_best.h5
#
# Epoch 553: val_loss improved from 0.08782 to 0.08740, saving model to iirs3_best.h5
#
# Epoch 554: val_loss improved from 0.08740 to 0.08698, saving model to iirs3_best.h5
#
# Epoch 555: val_loss improved from 0.08698 to 0.08657, saving model to iirs3_best.h5
#
# Epoch 556: val_loss improved from 0.08657 to 0.08618, saving model to iirs3_best.h5
#
# Epoch 557: val_loss improved from 0.08618 to 0.08580, saving model to iirs3_best.h5
#
# Epoch 558: val_loss improved from 0.08580 to 0.08543, saving model to iirs3_best.h5
#
# Epoch 559: val_loss improved from 0.08543 to 0.08506, saving model to iirs3_best.h5
#
# Epoch 560: val_loss improved from 0.08506 to 0.08469, saving model to iirs3_best.h5
#
# Epoch 561: val_loss improved from 0.08469 to 0.08432, saving model to iirs3_best.h5
#
# Epoch 562: val_loss improved from 0.08432 to 0.08394, saving model to iirs3_best.h5
#
# Epoch 563: val_loss improved from 0.08394 to 0.08355, saving model to iirs3_best.h5
#
# Epoch 564: val_loss improved from 0.08355 to 0.08315, saving model to iirs3_best.h5
#
# Epoch 565: val_loss improved from 0.08315 to 0.08274, saving model to iirs3_best.h5
#
# Epoch 566: val_loss improved from 0.08274 to 0.08236, saving model to iirs3_best.h5
#
# ...
#
# Epoch 813: val_loss improved from 0.04298 to 0.04290, saving model to iirs3_best.h5
#
# Epoch 814: val_loss improved from 0.04290 to 0.04281, saving model to iirs3_best.h5
#
# Epoch 815: val_loss improved from 0.04281 to 0.04273, saving model to iirs3_best.h5
#
# Epoch 816: val_loss improved from 0.04273 to 0.04268, saving model to iirs3_best.h5
#
# Epoch 817: val_loss improved from 0.04268 to 0.04262, saving model to iirs3_best.h5
#
# Epoch 818: val_loss improved from 0.04262 to 0.04256, saving model to iirs3_best.h5
#
# Epoch 819: val_loss improved from 0.04256 to 0.04249, saving model to iirs3_best.h5
#
# Epoch 820: val_loss improved from 0.04249 to 0.04243, saving model to iirs3_best.h5
#
# Epoch 821: val_loss improved from 0.04243 to 0.04236, saving model to iirs3_best.h5
#
# Epoch 822: val_loss improved from 0.04236 to 0.04228, saving model to iirs3_best.h5
#
# Epoch 823: val_loss improved from 0.04228 to 0.04221, saving model to iirs3_best.h5
#
# Epoch 824: val_loss improved from 0.04221 to 0.04213, saving model to iirs3_best.h5
#
# Epoch 825: val_loss improved from 0.04213 to 0.04205, saving model to iirs3_best.h5
#
# Epoch 826: val_loss improved from 0.04205 to 0.04200, saving model to iirs3_best.h5
#
# Epoch 827: val_loss improved from 0.04200 to 0.04195, saving model to iirs3_best.h5
#
# Epoch 828: val_loss improved from 0.04195 to 0.04190, saving model to iirs3_best.h5
#
# Epoch 829: val_loss improved from 0.04190 to 0.04184, saving model to iirs3_best.h5
#
# Epoch 830: val_loss improved from 0.04184 to 0.04177, saving model to iirs3_best.h5
#
# Epoch 831: val_loss improved from 0.04177 to 0.04170, saving model to iirs3_best.h5
#
# Epoch 832: val_loss improved from 0.04170 to 0.04163, saving model to iirs3_best.h5
#
# Epoch 833: val_loss improved from 0.04163 to 0.04155, saving model to iirs3_best.h5
#
# Epoch 834: val_loss improved from 0.04155 to 0.04148, saving model to iirs3_best.h5
#
# Epoch 835: val_loss improved from 0.04148 to 0.04140, saving model to iirs3_best.h5
#
# Epoch 836: val_loss improved from 0.04140 to 0.04132, saving model to iirs3_best.h5
#
# Epoch 837: val_loss improved from 0.04132 to 0.04128, saving model to iirs3_best.h5
#
# Epoch 838: val_loss improved from 0.04128 to 0.04123, saving model to iirs3_best.h5
#
# Epoch 839: val_loss improved from 0.04123 to 0.04117, saving model to iirs3_best.h5
#
# Epoch 840: val_loss improved from 0.04117 to 0.04111, saving model to iirs3_best.h5
#
# Epoch 841: val_loss improved from 0.04111 to 0.04105, saving model to iirs3_best.h5
#
# Epoch 842: val_loss improved from 0.04105 to 0.04098, saving model to iirs3_best.h5
#
# Epoch 843: val_loss improved from 0.04098 to 0.04091, saving model to iirs3_best.h5
#
# Epoch 844: val_loss improved from 0.04091 to 0.04084, saving model to iirs3_best.h5
#
# Epoch 845: val_loss improved from 0.04084 to 0.04077, saving model to iirs3_best.h5
#
# Epoch 846: val_loss improved from 0.04077 to 0.04069, saving model to iirs3_best.h5
#
# Epoch 847: val_loss improved from 0.04069 to 0.04065, saving model to iirs3_best.h5
#
# Epoch 848: val_loss improved from 0.04065 to 0.04060, saving model to iirs3_best.h5
#
# Epoch 849: val_loss improved from 0.04060 to 0.04055, saving model to iirs3_best.h5
#
# Epoch 850: val_loss improved from 0.04055 to 0.04050, saving model to iirs3_best.h5
#
# Epoch 851: val_loss improved from 0.04050 to 0.04044, saving model to iirs3_best.h5
#
# Epoch 852: val_loss improved from 0.04044 to 0.04038, saving model to iirs3_best.h5
#
# Epoch 853: val_loss improved from 0.04038 to 0.04031, saving model to iirs3_best.h5
#
# Epoch 854: val_loss improved from 0.04031 to 0.04024, saving model to iirs3_best.h5
#
# Epoch 855: val_loss improved from 0.04024 to 0.04017, saving model to iirs3_best.h5
#
# Epoch 856: val_loss improved from 0.04017 to 0.04010, saving model to iirs3_best.h5
#
# Epoch 857: val_loss improved from 0.04010 to 0.04003, saving model to iirs3_best.h5
#
# Epoch 858: val_loss improved from 0.04003 to 0.03995, saving model to iirs3_best.h5
#
# Epoch 859: val_loss improved from 0.03995 to 0.03991, saving model to iirs3_best.h5
#
# Epoch 860: val_loss improved from 0.03991 to 0.03986, saving model to iirs3_best.h5
#
# Epoch 861: val_loss improved from 0.03986 to 0.03982, saving model to iirs3_best.h5
#
# Epoch 862: val_loss improved from 0.03982 to 0.03976, saving model to iirs3_best.h5
#
# Epoch 863: val_loss improved from 0.03976 to 0.03971, saving model to iirs3_best.h5
#
# Epoch 864: val_loss improved from 0.03971 to 0.03965, saving model to iirs3_best.h5
#
# Epoch 865: val_loss improved from 0.03965 to 0.03959, saving model to iirs3_best.h5
#
# Epoch 866: val_loss improved from 0.03959 to 0.03952, saving model to iirs3_best.h5
#
# Epoch 867: val_loss improved from 0.03952 to 0.03945, saving model to iirs3_best.h5
#
# Epoch 868: val_loss improved from 0.03945 to 0.03939, saving model to iirs3_best.h5
#
# Epoch 869: val_loss improved from 0.03939 to 0.03932, saving model to iirs3_best.h5
#
# Epoch 870: val_loss improved from 0.03932 to 0.03928, saving model to iirs3_best.h5
#
# Epoch 871: val_loss improved from 0.03928 to 0.03923, saving model to iirs3_best.h5
#
# Epoch 872: val_loss improved from 0.03923 to 0.03919, saving model to iirs3_best.h5
#
# Epoch 873: val_loss improved from 0.03919 to 0.03914, saving model to iirs3_best.h5
#
# Epoch 874: val_loss improved from 0.03914 to 0.03908, saving model to iirs3_best.h5
#
# Epoch 875: val_loss improved from 0.03908 to 0.03903, saving model to iirs3_best.h5
#
# Epoch 876: val_loss improved from 0.03903 to 0.03897, saving model to iirs3_best.h5
#
# Epoch 877: val_loss improved from 0.03897 to 0.03891, saving model to iirs3_best.h5
#
# Epoch 878: val_loss improved from 0.03891 to 0.03884, saving model to iirs3_best.h5
#
# Epoch 879: val_loss improved from 0.03884 to 0.03878, saving model to iirs3_best.h5
#
# Epoch 880: val_loss improved from 0.03878 to 0.03871, saving model to iirs3_best.h5
#
# Epoch 881: val_loss improved from 0.03871 to 0.03864, saving model to iirs3_best.h5
#
# Epoch 882: val_loss improved from 0.03864 to 0.03860, saving model to iirs3_best.h5
#
# Epoch 883: val_loss improved from 0.03860 to 0.03856, saving model to iirs3_best.h5
#
# Epoch 884: val_loss improved from 0.03856 to 0.03852, saving model to iirs3_best.h5
#
# Epoch 885: val_loss improved from 0.03852 to 0.03847, saving model to iirs3_best.h5
#
# Epoch 886: val_loss improved from 0.03847 to 0.03842, saving model to iirs3_best.h5
#
# Epoch 887: val_loss improved from 0.03842 to 0.03836, saving model to iirs3_best.h5
#
# Epoch 888: val_loss improved from 0.03836 to 0.03830, saving model to iirs3_best.h5
#
# Epoch 889: val_loss improved from 0.03830 to 0.03825, saving model to iirs3_best.h5
#
# Epoch 890: val_loss improved from 0.03825 to 0.03818, saving model to iirs3_best.h5
#
# Epoch 891: val_loss improved from 0.03818 to 0.03812, saving model to iirs3_best.h5
#
# Epoch 892: val_loss improved from 0.03812 to 0.03806, saving model to iirs3_best.h5
#
# Epoch 893: val_loss improved from 0.03806 to 0.03802, saving model to iirs3_best.h5
#
# Epoch 894: val_loss improved from 0.03802 to 0.03799, saving model to iirs3_best.h5
#
# Epoch 895: val_loss improved from 0.03799 to 0.03795, saving model to iirs3_best.h5
#
# Epoch 896: val_loss improved from 0.03795 to 0.03790, saving model to iirs3_best.h5
#
# Epoch 897: val_loss improved from 0.03790 to 0.03785, saving model to iirs3_best.h5
#
# Epoch 898: val_loss improved from 0.03785 to 0.03780, saving model to iirs3_best.h5
#
# Epoch 899: val_loss improved from 0.03780 to 0.03774, saving model to iirs3_best.h5
#
# Epoch 900: val_loss improved from 0.03774 to 0.03769, saving model to iirs3_best.h5
#
# Epoch 901: val_loss improved from 0.03769 to 0.03763, saving model to iirs3_best.h5
#
# Epoch 902: val_loss improved from 0.03763 to 0.03757, saving model to iirs3_best.h5
#
# Epoch 903: val_loss improved from 0.03757 to 0.03751, saving model to iirs3_best.h5
#
# Epoch 904: val_loss improved from 0.03751 to 0.03744, saving model to iirs3_best.h5
#
# Epoch 905: val_loss improved from 0.03744 to 0.03738, saving model to iirs3_best.h5
#
# Epoch 906: val_loss improved from 0.03738 to 0.03735, saving model to iirs3_best.h5
#
# Epoch 907: val_loss improved from 0.03735 to 0.03731, saving model to iirs3_best.h5
#
# Epoch 908: val_loss improved from 0.03731 to 0.03727, saving model to iirs3_best.h5
#
# Epoch 909: val_loss improved from 0.03727 to 0.03723, saving model to iirs3_best.h5
#
# Epoch 910: val_loss improved from 0.03723 to 0.03718, saving model to iirs3_best.h5
#
# Epoch 911: val_loss improved from 0.03718 to 0.03713, saving model to iirs3_best.h5
#
# Epoch 912: val_loss improved from 0.03713 to 0.03708, saving model to iirs3_best.h5
#
# Epoch 913: val_loss improved from 0.03708 to 0.03702, saving model to iirs3_best.h5
#
# Epoch 914: val_loss improved from 0.03702 to 0.03697, saving model to iirs3_best.h5
#
# Epoch 915: val_loss improved from 0.03697 to 0.03691, saving model to iirs3_best.h5
#
# Epoch 916: val_loss improved from 0.03691 to 0.03686, saving model to iirs3_best.h5
#
# Epoch 917: val_loss improved from 0.03686 to 0.03680, saving model to iirs3_best.h5
#
# Epoch 918: val_loss improved from 0.03680 to 0.03674, saving model to iirs3_best.h5
#
# Epoch 919: val_loss improved from 0.03674 to 0.03671, saving model to iirs3_best.h5
#
# Epoch 920: val_loss improved from 0.03671 to 0.03667, saving model to iirs3_best.h5
#
# Epoch 921: val_loss improved from 0.03667 to 0.03663, saving model to iirs3_best.h5
#
# Epoch 922: val_loss improved from 0.03663 to 0.03659, saving model to iirs3_best.h5
#
# Epoch 923: val_loss improved from 0.03659 to 0.03655, saving model to iirs3_best.h5
#
# Epoch 924: val_loss improved from 0.03655 to 0.03650, saving model to iirs3_best.h5
#
# Epoch 925: val_loss improved from 0.03650 to 0.03645, saving model to iirs3_best.h5
#
# Epoch 926: val_loss improved from 0.03645 to 0.03640, saving model to iirs3_best.h5
#
# Epoch 927: val_loss improved from 0.03640 to 0.03635, saving model to iirs3_best.h5
#
# Epoch 928: val_loss improved from 0.03635 to 0.03629, saving model to iirs3_best.h5
#
# Epoch 929: val_loss improved from 0.03629 to 0.03624, saving model to iirs3_best.h5
#
# Epoch 930: val_loss improved from 0.03624 to 0.03618, saving model to iirs3_best.h5
#
# Epoch 931: val_loss improved from 0.03618 to 0.03615, saving model to iirs3_best.h5
#
# Epoch 932: val_loss improved from 0.03615 to 0.03612, saving model to iirs3_best.h5
#
# Epoch 933: val_loss improved from 0.03612 to 0.03608, saving model to iirs3_best.h5
#
# Epoch 934: val_loss improved from 0.03608 to 0.03604, saving model to iirs3_best.h5
#
# Epoch 935: val_loss improved from 0.03604 to 0.03600, saving model to iirs3_best.h5
#
# Epoch 936: val_loss improved from 0.03600 to 0.03595, saving model to iirs3_best.h5
#
# Epoch 937: val_loss improved from 0.03595 to 0.03591, saving model to iirs3_best.h5
#
# Epoch 938: val_loss improved from 0.03591 to 0.03586, saving model to iirs3_best.h5
#
# Epoch 939: val_loss improved from 0.03586 to 0.03581, saving model to iirs3_best.h5
#
# Epoch 940: val_loss improved from 0.03581 to 0.03576, saving model to iirs3_best.h5
#
# Epoch 941: val_loss improved from 0.03576 to 0.03570, saving model to iirs3_best.h5
#
# Epoch 942: val_loss improved from 0.03570 to 0.03565, saving model to iirs3_best.h5
#
# Epoch 943: val_loss improved from 0.03565 to 0.03560, saving model to iirs3_best.h5
#
# Epoch 944: val_loss improved from 0.03560 to 0.03554, saving model to iirs3_best.h5
#
# Epoch 945: val_loss improved from 0.03554 to 0.03551, saving model to iirs3_best.h5
#
# Epoch 946: val_loss improved from 0.03551 to 0.03548, saving model to iirs3_best.h5
#
# Epoch 947: val_loss improved from 0.03548 to 0.03545, saving model to iirs3_best.h5
#
# Epoch 948: val_loss improved from 0.03545 to 0.03541, saving model to iirs3_best.h5
#
# Epoch 949: val_loss improved from 0.03541 to 0.03537, saving model to iirs3_best.h5
#
# Epoch 950: val_loss improved from 0.03537 to 0.03533, saving model to iirs3_best.h5
#
# Epoch 951: val_loss improved from 0.03533 to 0.03528, saving model to iirs3_best.h5
#
# Epoch 952: val_loss improved from 0.03528 to 0.03524, saving model to iirs3_best.h5
#
# Epoch 953: val_loss improved from 0.03524 to 0.03519, saving model to iirs3_best.h5
#
# Epoch 954: val_loss improved from 0.03519 to 0.03514, saving model to iirs3_best.h5
#
# Epoch 955: val_loss improved from 0.03514 to 0.03510, saving model to iirs3_best.h5
#
# Epoch 956: val_loss improved from 0.03510 to 0.03505, saving model to iirs3_best.h5
#
# Epoch 957: val_loss improved from 0.03505 to 0.03500, saving model to iirs3_best.h5
#
# Epoch 958: val_loss improved from 0.03500 to 0.03494, saving model to iirs3_best.h5
#
# Epoch 959: val_loss improved from 0.03494 to 0.03492, saving model to iirs3_best.h5
#
# Epoch 960: val_loss improved from 0.03492 to 0.03489, saving model to iirs3_best.h5
#
# Epoch 961: val_loss improved from 0.03489 to 0.03486, saving model to iirs3_best.h5
#
# Epoch 962: val_loss improved from 0.03486 to 0.03482, saving model to iirs3_best.h5
#
# Epoch 963: val_loss improved from 0.03482 to 0.03479, saving model to iirs3_best.h5
#
# Epoch 964: val_loss improved from 0.03479 to 0.03475, saving model to iirs3_best.h5
#
# Epoch 965: val_loss improved from 0.03475 to 0.03471, saving model to iirs3_best.h5
#
# Epoch 966: val_loss improved from 0.03471 to 0.03466, saving model to iirs3_best.h5
#
# Epoch 967: val_loss improved from 0.03466 to 0.03462, saving model to iirs3_best.h5
#
# Epoch 968: val_loss improved from 0.03462 to 0.03458, saving model to iirs3_best.h5
#
# Epoch 969: val_loss improved from 0.03458 to 0.03453, saving model to iirs3_best.h5
#
# Epoch 970: val_loss improved from 0.03453 to 0.03448, saving model to iirs3_best.h5
#
# Epoch 971: val_loss improved from 0.03448 to 0.03444, saving model to iirs3_best.h5
#
# Epoch 972: val_loss improved from 0.03444 to 0.03441, saving model to iirs3_best.h5
#
# Epoch 973: val_loss improved from 0.03441 to 0.03439, saving model to iirs3_best.h5
#
# Epoch 974: val_loss improved from 0.03439 to 0.03436, saving model to iirs3_best.h5
#
# Epoch 975: val_loss improved from 0.03436 to 0.03432, saving model to iirs3_best.h5
#
# Epoch 976: val_loss improved from 0.03432 to 0.03429, saving model to iirs3_best.h5
#
# Epoch 977: val_loss improved from 0.03429 to 0.03425, saving model to iirs3_best.h5
#
# Epoch 978: val_loss improved from 0.03425 to 0.03421, saving model to iirs3_best.h5
#
# Epoch 979: val_loss improved from 0.03421 to 0.03417, saving model to iirs3_best.h5
#
# Epoch 980: val_loss improved from 0.03417 to 0.03413, saving model to iirs3_best.h5
#
# Epoch 981: val_loss improved from 0.03413 to 0.03409, saving model to iirs3_best.h5
#
# Epoch 982: val_loss improved from 0.03409 to 0.03405, saving model to iirs3_best.h5
#
# Epoch 983: val_loss improved from 0.03405 to 0.03400, saving model to iirs3_best.h5
#
# Epoch 984: val_loss improved from 0.03400 to 0.03396, saving model to iirs3_best.h5
#
# Epoch 985: val_loss improved from 0.03396 to 0.03391, saving model to iirs3_best.h5
#
# Epoch 986: val_loss improved from 0.03391 to 0.03387, saving model to iirs3_best.h5
#
# Epoch 987: val_loss improved from 0.03387 to 0.03384, saving model to iirs3_best.h5
#
# Epoch 988: val_loss improved from 0.03384 to 0.03382, saving model to iirs3_best.h5
#
# Epoch 989: val_loss improved from 0.03382 to 0.03379, saving model to iirs3_best.h5
#
# Epoch 990: val_loss improved from 0.03379 to 0.03376, saving model to iirs3_best.h5
#
# Epoch 991: val_loss improved from 0.03376 to 0.03373, saving model to iirs3_best.h5
#
# Epoch 992: val_loss improved from 0.03373 to 0.03369, saving model to iirs3_best.h5
#
# Epoch 993: val_loss improved from 0.03369 to 0.03366, saving model to iirs3_best.h5
#
# Epoch 994: val_loss improved from 0.03366 to 0.03362, saving model to iirs3_best.h5
#
# Epoch 995: val_loss improved from 0.03362 to 0.03358, saving model to iirs3_best.h5
#
# Epoch 996: val_loss improved from 0.03358 to 0.03354, saving model to iirs3_best.h5
#
# Epoch 997: val_loss improved from 0.03354 to 0.03350, saving model to iirs3_best.h5
#
# Epoch 998: val_loss improved from 0.03350 to 0.03346, saving model to iirs3_best.h5
#
# Epoch 999: val_loss improved from 0.03346 to 0.03341, saving model to iirs3_best.h5
#
# Epoch 1000: val_loss improved from 0.03341 to 0.03337, saving model to iirs3_best.h5

# %%
model.evaluate(X_test, Y_test)
# Out:
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1612 - accuracy: 0.9000
# [0.16116997599601746, 0.8999999761581421]

# %%
best_model = load_model('iris_best.h5')
best_model.evaluate(X_test, Y_test)

# %%
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1, len(y_acc)+1)

# %%
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, label='train accuracy')
plt.plot(xs, y_vloss, label='validation loss')
plt.legend(), plt.grid()
plt.ylim([0,1.2])
plt.xlabel('Epoch')
plt.show()
