# %% [markdown]
# # 회귀(Regression)
# - 사용 데이터: fetch_california_housing (켈리포니아 하우징)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
seed = 2022 
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
# 데이터 불러오기
from sklearn.datasets import fetch_california_housing
house = fetch_california_housing()
house.data.shape
# Out:
# (20640, 8)

# %%
# 
df = pd.DataFrame(house.data, columns=house.feature_names)
df['target'] = house.target
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  target
# 0    -122.23   4.526
# 1    -122.22   3.585
# 2    -122.24   3.521
# 3    -122.25   3.413
# 4    -122.25   3.422

# %%
df.shape
# Out:
# (20640, 9)

# %%
# 회귀시 표준화 잘 안해서 그냥 고고 
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    house.data, house.target, test_size = 0.1, random_state = seed # 분류와 다르게 테스트할게 많이 없으니 test_size = 0.1
) 
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((18576, 8), (2064, 8), (18576,), (2064,))

# %% [markdown]
# 2. 회귀 모델 정의/설정/학습/평가

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential([
                    Dense(20, input_dim=8, activation='relu'),
                    Dense(6, activation='relu'),
                    Dense(1)

])
model.summary()
### 회귀 #### 
# 노드 개수: 1
# 활성화 함수(activation): 사용 X (출력층에서)
# 손실 함수: mean_squared_error
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 20)                180
#
#  dense_7 (Dense)             (None, 6)                 126
#
#  dense_8 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 313
# Trainable params: 313
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss='mean_squared_error') 
# 회귀 -> metrics 사용 X 
# 회귀는 모델 단순화이기 때문

# %%
hist = model.fit(X_train, y_train, validation_split = 0.1,
                 epochs=100, batch_size=256)
# Out:
# Epoch 1/100
# 168/168 [==============================] - 2s 5ms/step - loss: 6100.0972 - val_loss: 11.1728
# Epoch 2/100
# 168/168 [==============================] - 0s 3ms/step - loss: 14.2590 - val_loss: 4.4969
# Epoch 3/100
# 168/168 [==============================] - 0s 3ms/step - loss: 11.4644 - val_loss: 5.5971
# Epoch 4/100
# 168/168 [==============================] - 1s 4ms/step - loss: 11.2878 - val_loss: 1.9589
# Epoch 5/100
# 168/168 [==============================] - 1s 3ms/step - loss: 11.2429 - val_loss: 1.4145
# Epoch 6/100
# 168/168 [==============================] - 0s 2ms/step - loss: 10.1894 - val_loss: 9.4110
# Epoch 7/100
# 168/168 [==============================] - 0s 2ms/step - loss: 9.5019 - val_loss: 3.4192
# Epoch 8/100
# 168/168 [==============================] - 0s 2ms/step - loss: 9.7525 - val_loss: 10.0946
# Epoch 9/100
# 168/168 [==============================] - 0s 2ms/step - loss: 8.8888 - val_loss: 82.8558
# Epoch 10/100
# 168/168 [==============================] - 0s 2ms/step - loss: 10.0762 - val_loss: 4.8935
# Epoch 11/100
# 168/168 [==============================] - 0s 2ms/step - loss: 8.9388 - val_loss: 0.9469
# Epoch 12/100
# 168/168 [==============================] - 0s 2ms/step - loss: 8.6942 - val_loss: 2.9250
# Epoch 13/100
# 168/168 [==============================] - 0s 2ms/step - loss: 8.3994 - val_loss: 0.8700
# Epoch 14/100
# 168/168 [==============================] - 0s 2ms/step - loss: 8.1619 - val_loss: 0.8941
# Epoch 15/100
# 168/168 [==============================] - 0s 2ms/step - loss: 7.9559 - val_loss: 3.9016
# Epoch 16/100
# 168/168 [==============================] - 0s 2ms/step - loss: 8.3276 - val_loss: 4.4918
# Epoch 17/100
# 168/168 [==============================] - 0s 2ms/step - loss: 7.9874 - val_loss: 1.2258
# Epoch 18/100
# 168/168 [==============================] - 0s 2ms/step - loss: 8.4018 - val_loss: 0.8752
# Epoch 19/100
100
# 168/168 [==============================] - 0s 2ms/step - loss: 5.2806 - val_loss: 10.4378
# Epoch 55/100
# 168/168 [==============================] - 0s 2ms/step - loss: 5.5925 - val_loss: 3.1585
# Epoch 56/100
# 168/168 [==============================] - 0s 2ms/step - loss: 5.4424 - val_loss: 1.0170
# Epoch 57/100
# 168/168 [==============================] - 0s 2ms/step - loss: 5.2755 - val_loss: 3.6892
# Epoch 58/100
# 168/168 [==============================] - 0s 2ms/step - loss: 5.0132 - val_loss: 5.2700
# Epoch 59/100
# 168/168 [==============================] - 0s 2ms/step - loss: 5.2393 - val_loss: 1.7503
# Epoch 60/100
# 168/168 [==============================] - 0s 2ms/step - loss: 5.0949 - val_loss: 4.0032
# Epoch 61/100
# 168/168 [==============================] - 0s 2ms/step - loss: 4.9616 - val_loss: 18.0774
# Epoch 62/100
# 168/168 [==============================] - 0s 2ms/step - loss: 5.0204 - val_loss: 25.8071
# Epoch 63/100
# 168/168 [==============================] - 0s 2ms/step - loss: 5.2580 - val_loss: 0.6745
# Epoch 64/100
# 168/168 [==============================] - 0s 2ms/step - loss: 4.8931 - val_loss: 4.2297
# Epoch 65/100
# 168/168 [==============================] - 0s 2ms/step - loss: 5.1888 - val_loss: 0.9662
# Epoch 66/100
# 168/168 [==============================] - 0s 2ms/step - loss: 4.8596 - val_loss: 1.5341
# Epoch 67/100
# 168/168 [==============================] - 0s 2ms/step - loss: 4.8486 - val_loss: 0.7323
# Epoch 68/100
# 168/168 [==============================] - 0s 2ms/step - loss: 4.7050 - val_loss: 42.2828
# Epoch 69/100
# 168/168 [==============================] - 0s 2ms/step - loss: 4.7421 - val_loss: 0.7510
# Epoch 70/100
# 168/168 [==============================] - 0s 2ms/step - loss: 4.5412 - val_loss: 1.1511
# Epoch 71/100
# 168/168 [==============================] - 0s 2ms/step - loss: 4.6431 - val_loss: 4.1022
# Epoch 72/100
# 168/168 [==============================] - 0s 2ms/step - loss: 5.2921 - val_loss: 0.7818
# Epoch 73/100
# 168/168 [==============================] - 0s 2ms/step - loss: 4.3615 - val_loss: 3.8446
# Epoch 74/100
# 168/168 [==============================] - 0s 2ms/step - loss: 4.6447 - val_loss: 0.6811
# Epoch 75/100
# 168/168 [==============================] - 0s 2ms/step - loss: 4.4524 - val_loss: 1.0989
# Epoch 76/100
# 168/168 [==============================] - 0s 2ms/step - loss: 4.3866 - val_loss: 1.4740
# Epoch 77/100
# 168/168 [==============================] - 0s 2ms/step - loss: 4.4725 - val_loss: 4.9636
# Epoch 78/100
# 168/168 [==============================] - 0s 2ms/step - loss: 4.1813 - val_loss: 0.7782
# Epoch 79/100
# 168/168 [==============================] - 0s 2ms/step - loss: 4.4099 - val_loss: 0.8158
# Epoch 80/100
# 168/168 [==============================] - 0s 2ms/step - loss: 4.0016 - val_loss: 1.0252
# Epoch 81/100
# 168/168 [==============================] - 0s 2ms/step - loss: 3.9064 - val_loss: 51.1423
# Epoch 82/100
# 168/168 [==============================] - 0s 2ms/step - loss: 4.0401 - val_loss: 1.6032
# Epoch 83/100
# 168/168 [==============================] - 0s 2ms/step - loss: 4.1410 - val_loss: 0.7701
# Epoch 84/100
# 168/168 [==============================] - 0s 2ms/step - loss: 3.9103 - val_loss: 0.7081
# Epoch 85/100
# 168/168 [==============================] - 0s 2ms/step - loss: 3.7563 - val_loss: 33.6851
# Epoch 86/100
# 168/168 [==============================] - 0s 2ms/step - loss: 3.9856 - val_loss: 48.8589
# Epoch 87/100
# 168/168 [==============================] - 0s 2ms/step - loss: 3.9528 - val_loss: 5.2652
# Epoch 88/100
# 168/168 [==============================] - 0s 2ms/step - loss: 4.4588 - val_loss: 0.7893
# Epoch 89/100
# 168/168 [==============================] - 0s 2ms/step - loss: 3.4752 - val_loss: 21.5886
# Epoch 90/100
# 168/168 [==============================] - 0s 2ms/step - loss: 3.7914 - val_loss: 0.6679
# Epoch 91/100
# 168/168 [==============================] - 0s 2ms/step - loss: 3.7554 - val_loss: 24.7682
# Epoch 92/100
# 168/168 [==============================] - 0s 2ms/step - loss: 3.5187 - val_loss: 1.3378
# Epoch 93/100
# 168/168 [==============================] - 0s 2ms/step - loss: 3.7831 - val_loss: 0.8831
# Epoch 94/100
# 168/168 [==============================] - 0s 2ms/step - loss: 3.7247 - val_loss: 3.2733
# Epoch 95/100
# 168/168 [==============================] - 0s 2ms/step - loss: 3.5218 - val_loss: 3.2803
# Epoch 96/100
# 168/168 [==============================] - 0s 2ms/step - loss: 3.5620 - val_loss: 0.6815
# Epoch 97/100
# 168/168 [==============================] - 0s 2ms/step - loss: 3.5165 - val_loss: 2.1957
# Epoch 98/100
# 168/168 [==============================] - 0s 2ms/step - loss: 3.8627 - val_loss: 1.2814
# Epoch 99/100
# 168/168 [==============================] - 0s 2ms/step - loss: 3.5538 - val_loss: 1.2571
# Epoch 100/100
# 168/168 [==============================] - 0s 2ms/step - loss: 3.3931 - val_loss: 1.6821

# %%
model.evaluate(X_test, y_test)
# Out:
# 65/65 [==============================] - 0s 2ms/step - loss: 1.7738
# 1.7737537622451782

# %%
y_loss = hist.history['loss']
y_vloss = hist.history['val_loss']
xs = np.arange(1, len(y_loss)+1)

# %%
plt.figure(figsize=(12,8))
plt.plot(xs, y_loss, label='train loss')
plt.plot(xs, y_vloss, label='validation loss')
plt.legend(), plt.grid(), plt.ylim(0,300)
plt.xlabel('Epoch')
plt.show()

# %% [markdown]
# ### 평가

# %%
pred = model.predict(X_test) # .evaluate 도 있음

# %%
dft = pd.DataFrame({'y_test': y_test, 'pred': pred.flatten()})
dft.head()
# Out:
#    y_test      pred
# 0   4.771  2.792676
# 1   1.371  0.897531
# 2   1.233 -0.077168
# 3   0.938  1.007934
# 4   3.260  2.308604

# %%
from sklearn.metrics import mean_squared_error, r2_score
mean_squared_error(y_test, pred), r2_score(y_test, pred)
# pred 음수값 -> 그래프상 데이터가 막 튀는 구간이 많아서, 데이터 잘 예측 못해서?
# Out:
# (1.773754321268171, -0.38205215481283594)
